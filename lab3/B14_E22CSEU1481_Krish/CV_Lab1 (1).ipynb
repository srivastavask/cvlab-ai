# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-c05f82bd-725a-46ea-8915-3b609334466b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c05f82bd-725a-46ea-8915-3b609334466b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import cv2
import matplotlib.pyplot as plt

# Helper function to display images
def show_image(img, title):
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    plt.title(title)
    plt.axis('off')
    plt.show()

# Load the image
image = cv2.imread('Picture_1_CV.jpg')

if image is None:
    print("Error: Image not found! Please upload the file with the correct name.")
else:
    show_image(image, "Original Image")

# %%
def translate_image(img, tx, ty):
    rows, cols = img.shape[:2]
    translation_matrix = np.float32([[1, 0, tx], [0, 1, ty]])
    return cv2.warpAffine(img, translation_matrix, (cols, rows))

translated_image = translate_image(image, 50, 100)
show_image(translated_image, "Translated Image")

# %%
def scale_image(img, fx, fy):
    return cv2.resize(img, None, fx=fx, fy=fy, interpolation=cv2.INTER_LINEAR)

scaled_image = scale_image(image, 1.5, 1.5)
show_image(scaled_image, "Scaled Image")

# %%
def rotate_image(img, angle):
    rows, cols = img.shape[:2]
    rotation_matrix = cv2.getRotationMatrix2D((cols / 2, rows / 2), angle, 1)
    return cv2.warpAffine(img, rotation_matrix, (cols, rows))

rotated_image = rotate_image(image, 45)
show_image(rotated_image, "Rotated Image")

# %%
def reflect_image(img, axis):
    if axis == 'x':
        return cv2.flip(img, 0)
    elif axis == 'y':
        return cv2.flip(img, 1)

reflected_image_x = reflect_image(image, 'x')
show_image(reflected_image_x, "Reflected Image (X-axis)")

reflected_image_y = reflect_image(image, 'y')
show_image(reflected_image_y, "Reflected Image (Y-axis)")

# %%
def crop_image(img, x_start, x_end, y_start, y_end):
    return img[y_start:y_end, x_start:x_end]

cropped_image = crop_image(image, 50, 200, 50, 200)
show_image(cropped_image, "Cropped Image")

# %%
def shear_image_x(img, shear_factor):
    rows, cols = img.shape[:2]
    shear_matrix = np.float32([[1, shear_factor, 0], [0, 1, 0]])
    return cv2.warpAffine(img, shear_matrix, (cols + int(shear_factor * rows), rows))

sheared_image_x = shear_image_x(image, 0.5)
show_image(sheared_image_x, "Sheared Image (X-axis)")

# %%
def shear_image_y(img, shear_factor):
    rows, cols = img.shape[:2]
    shear_matrix = np.float32([[1, 0, 0], [shear_factor, 1, 0]])
    return cv2.warpAffine(img, shear_matrix, (cols, rows + int(shear_factor * cols)))

sheared_image_y = shear_image_y(image, 0.5)
show_image(sheared_image_y, "Sheared Image (Y-axis)")

# %%
# Check the dimensions of the original image
print(f"Original Image Shape: {image.shape}")

# Check the dimensions of the scaled image
print(f"Scaled Image Shape: {scaled_image.shape}")
# Out:
# Original Image Shape: (768, 768, 3)
# Scaled Image Shape: (1152, 1152, 3)
