# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

image_path = "Picture1.jpg"
image_bgr = cv2.imread(image_path)


cv2_imshow(image_bgr)


height, width, channels = image_bgr.shape
print(f"Image Size: {width}x{height}, Channels: {channels}")


total_pixels = height * width
print(f"Total Pixels: {total_pixels}")


image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)
cv2_imshow(image_rgb)


image_gray = cv2.cvtColor(image_rgb, cv2.COLOR_RGB2GRAY)
cv2_imshow(image_gray)


_, image_binary = cv2.threshold(image_gray, 127, 255, cv2.THRESH_BINARY)
cv2_imshow(image_binary)

black_pixels = np.sum(image_binary == 0)
print(f"Area of Black Pixels: {black_pixels}")


binary_height, binary_width = image_binary.shape
print(f"Binary Image Size: {binary_width}x{binary_height}")
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>
# Image Size: 512x512, Channels: 3
# Total Pixels: 262144
# <PIL.Image.Image image mode=RGB size=512x512>
# <PIL.Image.Image image mode=L size=512x512>
# <PIL.Image.Image image mode=L size=512x512>
# Area of Black Pixels: 199285
# Binary Image Size: 512x512
