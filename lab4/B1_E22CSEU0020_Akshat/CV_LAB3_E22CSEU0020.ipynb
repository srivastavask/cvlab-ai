# %% [markdown]
# **Akshat Aggarwal**

# %% [markdown]
# **E22CSEU0020**

# %% [markdown]
# **Question:-1**

# %%
import cv2
from google.colab.patches import cv2_imshow
import numpy as np
import matplotlib.pyplot as plt

# %%
image=cv2.imread("/content/cv lab3.jpeg")
plt.imshow(image)
plt.axis('off')
plt.show()

# %%
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

plt.imshow(image_rgb)
plt.axis('off')
plt.show()

# %%
height, width, channels = image.shape
print(f"Image Size: Width={width}, Height={height}, Channels={channels}")
# Out:
# Image Size: Width=261, Height=148, Channels=3

# %%
total_pixels = height * width
total_pixels
# Out:
# 38628

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
plt.imshow(gray_image, cmap='gray')
plt.axis('off')
plt.show()

# %%
_, binary = cv2.threshold(gray_image, 127, 255, cv2.THRESH_BINARY)
cv2_imshow(binary)
# Out:
# <PIL.Image.Image image mode=L size=261x148>

# %%
binary.shape
# Out:
# (148, 261)

# %%
black_pixels = np.sum(binary == 0)
black_pixels
# Out:
# 16947

# %% [markdown]
# **Question:-2**

# %%
sobel = cv2.Sobel(image, cv2.CV_64F, 1, 1, ksize=5)
cv2_imshow(sobel)
# Out:
# <PIL.Image.Image image mode=RGB size=261x148>

# %%
sobel = cv2.Sobel(image, cv2.CV_64F, 1, 0, ksize=5)
cv2_imshow(sobel)
# Out:
# <PIL.Image.Image image mode=RGB size=261x148>

# %%
sobel = cv2.Sobel(image, cv2.CV_64F, 0, 1, ksize=5)
cv2_imshow(sobel)
# Out:
# <PIL.Image.Image image mode=RGB size=261x148>

# %%
sobel = cv2.Sobel(gray_image, cv2.CV_64F, 0, 1, ksize=5)
cv2_imshow(sobel)
# Out:
# <PIL.Image.Image image mode=L size=261x148>

# %%
sobel = cv2.Sobel(gray_image, cv2.CV_64F, 1, 0, ksize=5)
cv2_imshow(sobel)
# Out:
# <PIL.Image.Image image mode=L size=261x148>

# %%
sobel = cv2.Sobel(gray_image, cv2.CV_64F, 1, 1, ksize=5)
cv2_imshow(sobel)
# Out:
# <PIL.Image.Image image mode=L size=261x148>

# %%
prewitt_x = cv2.filter2D(image, -1, np.array([[-1, 0, 1], [-1, 0, 1], [-1, 0, 1]]))
cv2_imshow(prewitt_x)
# Out:
# <PIL.Image.Image image mode=RGB size=261x148>

# %%
prewitt_x = cv2.filter2D(gray_image, -1, np.array([[-1, 0, 1], [-1, 0, 1], [-1, 0, 1]]))
cv2_imshow(prewitt_x)
# Out:
# <PIL.Image.Image image mode=L size=261x148>

# %%
roberts_x = cv2.filter2D(image, -1, np.array([[1, 0], [0, -1]]))
cv2_imshow(roberts_x)
# Out:
# <PIL.Image.Image image mode=RGB size=261x148>

# %%
roberts_x = cv2.filter2D(gray_image, -1, np.array([[1, 0], [0, -1]]))
cv2_imshow(roberts_x)
# Out:
# <PIL.Image.Image image mode=L size=261x148>

# %%
canny = cv2.Canny(image, 100, 200)
cv2_imshow(canny)
# Out:
# <PIL.Image.Image image mode=L size=261x148>

# %%
canny = cv2.Canny(gray_image, 100, 200)
cv2_imshow(canny)
# Out:
# <PIL.Image.Image image mode=L size=261x148>

# %%
_, global_thresh = cv2.threshold(image, 127, 255, cv2.THRESH_BINARY)
cv2_imshow(global_thresh)
# Out:
# <PIL.Image.Image image mode=RGB size=261x148>

# %%
_, global_thresh = cv2.threshold(gray_image, 127, 255, cv2.THRESH_BINARY)
cv2_imshow( global_thresh)
# Out:
# <PIL.Image.Image image mode=L size=261x148>

# %%
adaptive_thresh = cv2.adaptiveThreshold(gray_image, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 11, 2)
cv2_imshow(adaptive_thresh)
# Out:
# <PIL.Image.Image image mode=L size=261x148>

# %%
watershed = image.copy()
gray_blur = cv2.GaussianBlur(gray_image, (5,5), 0)

# %%
_, markers = cv2.threshold(gray_blur, 127, 255, cv2.THRESH_BINARY)
markers = cv2.watershed(image, cv2.connectedComponents(markers)[1])
watershed[markers == -1] = [255, 0, 0]
cv2_imshow(watershed)
# Out:
# <PIL.Image.Image image mode=RGB size=261x148>
