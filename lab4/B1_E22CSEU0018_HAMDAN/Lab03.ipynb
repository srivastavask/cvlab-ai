# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

image_path = "/content/download.jpg"
image = cv2.imread(image_path)

cv2_imshow(image)

height, width, channels = image.shape
print(f"Image Size: {width} x {height} pixels")
print(f"Total Pixels: {width * height}")

gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2.imwrite("gray_image.jpg", gray_image)

cv2_imshow(gray_image)
_, binary_image = cv2.threshold(gray_image, 127, 255, cv2.THRESH_BINARY)
cv2.imwrite("binary_image.jpg", binary_image)

black_pixels = np.sum(binary_image == 0)
print(f"Black Pixel Count: {black_pixels}")

cv2_imshow(binary_image)
# Out:
# <PIL.Image.Image image mode=RGB size=289x405>
# Image Size: 289 x 405 pixels
# Total Pixels: 117045
# <PIL.Image.Image image mode=L size=289x405>
# Black Pixel Count: 71058
# <PIL.Image.Image image mode=L size=289x405>

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
from skimage.filters import prewitt_h, prewitt_v, roberts
import matplotlib.pyplot as plt

prewitt_x = prewitt_h(gray_image)
prewitt_y = prewitt_v(gray_image)
prewitt_combined = np.hypot(prewitt_x, prewitt_y)

roberts = roberts(gray_image)


canny_edges = cv2.Canny(gray_image, 100, 200)

plt.figure(figsize=(10,10 ))
plt.subplot(2, 2, 1)
plt.imshow(sobel_combined, cmap="gray")
plt.title("Sobel Operator")

plt.subplot(2, 2, 2)
plt.imshow(prewitt_combined, cmap="gray")
plt.title("Prewitt Operator")

plt.subplot(2, 2, 3)
plt.imshow(roberts, cmap="gray")
plt.title("Roberts Operator")

plt.subplot(2, 2, 4)
plt.imshow(canny_edges, cmap="gray")
plt.title("Canny Edge Detection")

plt.show()
