# %%
# !pip install xmltodict
import os, cv2, random, xmltodict, torch, pandas as pd, numpy as np 
from glob import glob
from PIL import Image
from torch.utils.data import random_split, Dataset, DataLoader
from matplotlib import pyplot as plt
class ObjectDetectionCustomDataset(Dataset): 
    
    def __init__(self, root, transformations = None, size = 224, im_files = [".jpg", ".png", ".jpeg"]):
        
        self.root, self.size, self.transformations = root, size, transformations
        self.class_names, self.class_counts = {}, 0
        self.data_info = sorted(glob(f"{root}/annotations/*.xml"))
        for idx, data_info in enumerate(self.data_info):
            
            info = xmltodict.parse(open(f"{data_info}","r").read())

            bbox_info = info["annotation"]["object"]
            if isinstance(bbox_info, list):
                for bb_info in bbox_info:
                    if class_name not in self.class_names: self.class_names[class_name] = self.class_counts; self.class_counts += 1

            elif isinstance(bbox_info, dict): 
                for bb_info in bbox_info:
                    class_name = bbox_info["name"]
                    if class_name not in self.class_names: self.class_names[class_name] = self.class_counts; self.class_counts += 1

    def __len__(self): return len(self.data_info)

    def get_info(self, idx): return xmltodict.parse(open(f"{self.data_info[idx]}","r").read())
    
    def read_im(self, info): return Image.open(f"{self.root}/images/{info['annotation']['filename']}").convert("RGB")

    def get_coordinates(self, bbox): return float(bbox["xmin"]), float(bbox["ymin"]), float(bbox["xmax"]), float(bbox["ymax"])
    
    def get_bboxes(self, info):
        
        bboxes, class_names = [], []
        bbox_info = info["annotation"]["object"]
        
        if isinstance(bbox_info, list):
            for bb_info in bbox_info:
                bbox = bb_info["bndbox"]
                class_name = bb_info["name"]
                class_names.append(class_name)
                bboxes.append(self.get_coordinates(bbox))
        elif isinstance(bbox_info, dict): 
            for bb_info in bbox_info:
                if bb_info == "bndbox":
                    bbox = bbox_info[bb_info]
                    class_name = bbox_info["name"]
                    bboxes.append(self.get_coordinates(bbox))
                    class_names.append(class_name)
                    
        return torch.as_tensor(bboxes, dtype = torch.float32), class_names
        
    def get_label(self, class_name): return self.class_names[class_name]
    
    def get_area(self, bboxes): return (bboxes[:, 3] - bboxes[:, 1]) * (bboxes[:, 2] - bboxes[:, 0])

    def create_target(self, bboxes, labels, image_id, area, is_crowd): target = {}; target["boxes"] = bboxes; target["labels"] = labels; target["image_id"] = image_id; target["area"] = area; target["iscrowd"] = is_crowd; return target
        
    def __getitem__(self, idx):
        
        info = self.get_info(idx)
        im = self.read_im(info)
        bboxes, class_names = self.get_bboxes(info)
        labels = torch.tensor([self.get_label(class_name) for class_name in class_names], dtype = torch.int64)
        
        image_id = torch.tensor([idx])
        area = self.get_area(bboxes)
        is_crowd = torch.zeros((len(bboxes), ), dtype = torch.int64)
        
        target = self.create_target(bboxes, labels, image_id, area, is_crowd)

        if self.transformations is not None: im, target = self.transformations(im, target)
        
        return im, target

def custom_collate_fn(batch): return tuple(zip(*batch))
# train 80%, val: 10%, test: 10%
def get_dls(root, transformations, bs, split = [0.8, 0.1], ns = 4):
    
    ds = ObjectDetectionCustomDataset(root = root, transformations = transformations)
    
    all_len = len(ds); tr_len = int(all_len * split[0]); val_len = int(all_len * split[1])
    tr_ds, val_ds, ts_ds = random_split(dataset = ds, lengths = [tr_len, val_len, all_len - tr_len - val_len])
    
    tr_dl, val_dl, ts_dl = DataLoader(tr_ds, batch_size = bs, collate_fn = custom_collate_fn, shuffle = True, num_workers = ns), DataLoader(val_ds, batch_size = bs, collate_fn = custom_collate_fn, shuffle = False, num_workers = ns), DataLoader(ts_ds, batch_size = 1, collate_fn = custom_collate_fn, shuffle = False, num_workers = ns)
    
    return tr_dl, val_dl, ts_dl, ds.class_names
# Out:
# Collecting xmltodict
#   Downloading xmltodict-0.14.2-py2.py3-none-any.whl.metadata (8.0 kB)
# Downloading xmltodict-0.14.2-py2.py3-none-any.whl (10.0 kB)
# Installing collected packages: xmltodict
# Successfully installed xmltodict-0.14.2

# %%
from torch import Tensor
from torchvision.transforms import functional as F, transforms as T
from typing import Dict, Optional, Tuple, List

class Compose:
    def __init__(self, transforms):
        self.transforms = transforms

    def __call__(self, image, target):
        for t in self.transforms:
            image, target = t(image, target)
        return image, target
#Convert from PIL to Tensor
class PILToTensor(torch.nn.Module):
    def forward(
        self, image: Tensor, target: Optional[Dict[str, Tensor]] = None
    ) -> Tuple[Tensor, Optional[Dict[str, Tensor]]]:
        image = F.pil_to_tensor(image)
        return image, target
#Normalize data to the same form, mean
class Normalize(torch.nn.Module):
    def forward(self, image: Tensor, target: Optional, mean: List[float] = [0.485, 0.456, 0.406], std: List[float] = [0.229, 0.224, 0.225]):
        image = F.normalize(tensor = image, mean = mean, std = std)
        return image, target
    
class ConvertImageDtype(torch.nn.Module):
    def __init__(self, dtype: torch.dtype) -> None:
        super().__init__()
        self.dtype = dtype

    def forward(
        self, image: Tensor, target: Optional[Dict[str, Tensor]] = None
    ) -> Tuple[Tensor, Optional[Dict[str, Tensor]]]:
        image = F.convert_image_dtype(image, self.dtype)
        return image, target
class RandomHorizontalFlip(T.RandomHorizontalFlip):
    def forward(
        self, image: Tensor, target: Optional[Dict[str, Tensor]] = None
    ) -> Tuple[Tensor, Optional[Dict[str, Tensor]]]:
        if torch.rand(1) < self.p:
            image = F.hflip(image)
            if target is not None:
                _, _, width = F.get_dimensions(image)
                if "masks" in target:
                    target["masks"] = target["masks"].flip(-1)
                if "keypoints" in target:
                    keypoints = target["keypoints"]
                    keypoints = _flip_coco_person_keypoints(keypoints, width)
                    target["keypoints"] = keypoints
        return image, target

def get_transform(train):
    
    transformations = []
    transformations.append(PILToTensor())
    transformations.append(ConvertImageDtype(torch.float))
    transformations.append(Normalize())
    
    if train: transformations.append(RandomHorizontalFlip(0.5))
    
    return Compose(transformations)

tfs = get_transform(train = False)
data_path = "/kaggle/input/road-sign-detection"
tr_dl, val_dl, ts_dl, class_names = get_dls(root = data_path, transformations = tfs, bs = 4) #Mỗi lần huấn luyện sẽ xử lý 4 tensor cùng lúc
print(len(tr_dl), len(val_dl), len(ts_dl), class_names)
# Out:
# 176 22 89 {'trafficlight': 0, 'speedlimit': 1, 'crosswalk': 2, 'stop': 3}

# %%
def tensor_2_im(t, t_type = "rgb", inv_trans = False):
    
    assert t_type in ["rgb", "gray"], "Determine whether the image is RGB or grayscale."
    gray_tfs = T.Compose([T.Normalize(mean = [ 0.], std = [1/0.5]), T.Normalize(mean = [-0.5], std = [1])])
    rgb_tfs  = T.Compose([T.Normalize(mean = [ 0., 0., 0. ], std = [ 1/0.229, 1/0.224, 1/0.225 ]), T.Normalize(mean = [ -0.485, -0.456, -0.406 ], std = [ 1., 1., 1. ])])
    
    invTrans = gray_tfs if t_type == "gray" else rgb_tfs 
    
    return (invTrans(t) * 255).detach().cpu().permute(1,2,0).numpy().astype(np.uint8) if inv_trans else (t * 255).detach().cpu().permute(1,2,0).numpy().astype(np.uint8)

def visualize(data, n_ims, rows, cmap = None):
    
    assert cmap in ["rgb", "gray"], "Determine whether the image is black and white or colored!"
    if cmap == "rgb": cmap = "viridis"
    
    plt.figure(figsize = (20, 10))
    indekslar = [random.randint(0, len(data) - 1) for _ in range(n_ims)]
    for idx, indeks in enumerate(indekslar):
        im, target = data[indeks]
        img = tensor_2_im(im, inv_trans = True)
        bbox_class_names = []
        for i, cntr in enumerate(target["boxes"]):
            r, g, b = [random.randint(0, 255) for _ in range(3)]
            x, y, w, h = [round(c.item()) for c in cntr]
            bbox_class_names.append(list(class_names.keys())[target["labels"][i].item()])
            cv2.rectangle(img = img, pt1 = (x, y), pt2 = (w, h), color = (r, g, b), thickness = 2)
        bbox_class_names = [bbox_class_name for bbox_class_name in bbox_class_names]
        plt.subplot(rows, n_ims // rows, idx + 1)
        
        plt.imshow(img); plt.title(f"{bbox_class_names}")
        
        plt.axis("off")
        
visualize(tr_dl.dataset, 20, 4, "rgb")

# %%
from torchvision.models.detection import fasterrcnn_resnet50_fpn

m = fasterrcnn_resnet50_fpn(weights = "DEFAULT")
device, num_classes = "cuda", len(class_names)

# get number of input features for the classifier
in_features = m.roi_heads.box_predictor.cls_score.in_features
# replace the pre-trained head with a new one
m.roi_heads.box_predictor.cls_score = torch.nn.Linear(in_features, num_classes)
m.roi_heads.box_predictor.bbox_pred = torch.nn.Linear(in_features, num_classes * 4)
m.to(device)
optimizer = torch.optim.SGD(m.parameters(), lr = 0.001, momentum = 0.9, weight_decay = 0.0005)
# and a learning rate scheduler
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size = 3, gamma = 0.1)
# Out:
# Downloading: "https://download.pytorch.org/models/fasterrcnn_resnet50_fpn_coco-258fb6c6.pth" to /root/.cache/torch/hub/checkpoints/fasterrcnn_resnet50_fpn_coco-258fb6c6.pth
# 100%|██████████| 160M/160M [00:00<00:00, 202MB/s]

# %%
# !pip install pycocotools
import torch.distributed as dist, datetime
from pycocotools.coco import COCO
from pycocotools.cocoeval import COCOeval
import pycocotools.mask as mask_util
from contextlib import redirect_stdout
import copy, io

class CocoEvaluator:
    def __init__(self, coco_gt, iou_types):
        if not isinstance(iou_types, (list, tuple)):
            raise TypeError(f"This constructor expects iou_types of type list or tuple, instead  got {type(iou_types)}")
        coco_gt = copy.deepcopy(coco_gt)
        self.coco_gt = coco_gt

        self.iou_types = iou_types
        self.coco_eval = {}
        for iou_type in iou_types:
            self.coco_eval[iou_type] = COCOeval(coco_gt, iouType=iou_type)

        self.img_ids = []
        self.eval_imgs = {k: [] for k in iou_types}

    def update(self, predictions):
        img_ids = list(np.unique(list(predictions.keys())))
        self.img_ids.extend(img_ids)

        for iou_type in self.iou_types:
            results = self.prepare(predictions, iou_type)
            with redirect_stdout(io.StringIO()):
                coco_dt = COCO.loadRes(self.coco_gt, results) if results else COCO()
            coco_eval = self.coco_eval[iou_type]

            coco_eval.cocoDt = coco_dt
            coco_eval.params.imgIds = list(img_ids)
            img_ids, eval_imgs = evaluate_coco(coco_eval)

            self.eval_imgs[iou_type].append(eval_imgs)

    def synchronize_between_processes(self):
        for iou_type in self.iou_types:
            self.eval_imgs[iou_type] = np.concatenate(self.eval_imgs[iou_type], 2)
            create_common_coco_eval(self.coco_eval[iou_type], self.img_ids, self.eval_imgs[iou_type])

    def accumulate(self):
        for coco_eval in self.coco_eval.values():
            coco_eval.accumulate()

    def summarize(self):
        for iou_type, coco_eval in self.coco_eval.items():
            print(f"IoU metric: {iou_type}")
            coco_eval.summarize()

    def prepare(self, predictions, iou_type):
        if iou_type == "bbox":
            return self.prepare_for_coco_detection(predictions)
        if iou_type == "segm":
            return self.prepare_for_coco_segmentation(predictions)
        if iou_type == "keypoints":
            return self.prepare_for_coco_keypoint(predictions)
        raise ValueError(f"Unknown iou type {iou_type}")

    def prepare_for_coco_detection(self, predictions):
        coco_results = []
        for original_id, prediction in predictions.items():
            if len(prediction) == 0:
                continue

            boxes = prediction["boxes"]
            boxes = convert_to_xywh(boxes).tolist()
            scores = prediction["scores"].tolist()
            labels = prediction["labels"].tolist()

            coco_results.extend(
                [
                    {
                        "image_id": original_id,
                        "category_id": labels[k],
                        "bbox": box,
                        "score": scores[k],
                    }
                    for k, box in enumerate(boxes)
                ]
            )
        return coco_results

    def prepare_for_coco_segmentation(self, predictions):
        coco_results = []
        for original_id, prediction in predictions.items():
            if len(prediction) == 0:
                continue

            scores = prediction["scores"]
            labels = prediction["labels"]
            masks = prediction["masks"]

            masks = masks > 0.5

            scores = prediction["scores"].tolist()
            labels = prediction["labels"].tolist()

            rles = [
                mask_util.encode(np.array(mask[0, :, :, np.newaxis], dtype=np.uint8, order="F"))[0] for mask in masks
            ]
            for rle in rles:
                rle["counts"] = rle["counts"].decode("utf-8")

            coco_results.extend(
                [
                    {
                        "image_id": original_id,
                        "category_id": labels[k],
                        "segmentation": rle,
                        "score": scores[k],
                    }
                    for k, rle in enumerate(rles)
                ]
            )
        return coco_results

    def prepare_for_coco_keypoint(self, predictions):
        coco_results = []
        for original_id, prediction in predictions.items():
            if len(prediction) == 0:
                continue

            boxes = prediction["boxes"]
            boxes = convert_to_xywh(boxes).tolist()
            scores = prediction["scores"].tolist()
            labels = prediction["labels"].tolist()
            keypoints = prediction["keypoints"]
            keypoints = keypoints.flatten(start_dim=1).tolist()

            coco_results.extend(
                [
                    {
                        "image_id": original_id,
                        "category_id": labels[k],
                        "keypoints": keypoint,
                        "score": scores[k],
                    }
                    for k, keypoint in enumerate(keypoints)
                ]
            )
        return coco_results


def convert_to_xywh(boxes):
    xmin, ymin, xmax, ymax = boxes.unbind(1)
    return torch.stack((xmin, ymin, xmax - xmin, ymax - ymin), dim=1)


def merge(img_ids, eval_imgs):
    all_img_ids = all_gather(img_ids)
    all_eval_imgs = all_gather(eval_imgs)

    merged_img_ids = []
    for p in all_img_ids:
        merged_img_ids.extend(p)

    merged_eval_imgs = []
    for p in all_eval_imgs:
        merged_eval_imgs.append(p)

    merged_img_ids = np.array(merged_img_ids)
    merged_eval_imgs = np.concatenate(merged_eval_imgs, 2)

    # keep only unique (and in sorted order) images
    merged_img_ids, idx = np.unique(merged_img_ids, return_index=True)
    merged_eval_imgs = merged_eval_imgs[..., idx]

    return merged_img_ids, merged_eval_imgs


def create_common_coco_eval(coco_eval, img_ids, eval_imgs):
    img_ids, eval_imgs = merge(img_ids, eval_imgs)
    img_ids = list(img_ids)
    eval_imgs = list(eval_imgs.flatten())

    coco_eval.evalImgs = eval_imgs
    coco_eval.params.imgIds = img_ids
    coco_eval._paramsEval = copy.deepcopy(coco_eval.params)


def evaluate_coco(imgs):
    with redirect_stdout(io.StringIO()):
        imgs.evaluate()
    return imgs.params.imgIds, np.asarray(imgs.evalImgs).reshape(-1, len(imgs.params.areaRng), len(imgs.params.imgIds))


def all_gather(data):
    """
    Run all_gather on arbitrary picklable data (not necessarily tensors)
    Args:
        data: any picklable object
    Returns:
        list[data]: list of data gathered from each rank
    """
    world_size = get_world_size()
    if world_size == 1:
        return [data]
    data_list = [None] * world_size
    dist.all_gather_object(data_list, data)
    return data_list
# Out:
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.11/dist-packages (2.0.8)
# Requirement already satisfied: matplotlib>=2.1.0 in /usr/local/lib/python3.11/dist-packages (from pycocotools) (3.7.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from pycocotools) (1.26.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.1.0->pycocotools) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.1.0->pycocotools) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.1.0->pycocotools) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.1.0->pycocotools) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.1.0->pycocotools) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.1.0->pycocotools) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.1.0->pycocotools) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.1.0->pycocotools) (2.9.0.post0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy->pycocotools) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy->pycocotools) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy->pycocotools) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy->pycocotools) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy->pycocotools) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy->pycocotools) (2.4.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=2.1.0->pycocotools) (1.17.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->pycocotools) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->pycocotools) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy->pycocotools) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy->pycocotools) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy->pycocotools) (2024.2.0)

# %%
import math, sys, time, torch, torchvision
import torchvision.models.detection.mask_rcnn
from pycocotools.coco import COCO
from pycocotools import mask as coco_mask
from collections import defaultdict, deque

def convert_to_coco_api(ds):
    coco_ds = COCO()
    # annotation IDs need to start at 1, not 0, see torchvision issue #1530
    ann_id = 1
    dataset = {"images": [], "categories": [], "annotations": []}
    categories = set()
    for img_idx in range(len(ds)):
        # find better way to get target
        # targets = ds.get_annotations(img_idx)
        img, targets = ds[img_idx]
        image_id = targets["image_id"].item()
        img_dict = {}
        img_dict["id"] = image_id
        img_dict["height"] = img.shape[-2]
        img_dict["width"] = img.shape[-1]
        dataset["images"].append(img_dict)
        bboxes = targets["boxes"].clone()
        bboxes[:, 2:] -= bboxes[:, :2]
        bboxes = bboxes.tolist()
        labels = targets["labels"].tolist()
        areas = targets["area"].tolist()
        iscrowd = targets["iscrowd"].tolist()
        if "masks" in targets:
            masks = targets["masks"]
            # make masks Fortran contiguous for coco_mask
            masks = masks.permute(0, 2, 1).contiguous().permute(0, 2, 1)
        if "keypoints" in targets:
            keypoints = targets["keypoints"]
            keypoints = keypoints.reshape(keypoints.shape[0], -1).tolist()
        num_objs = len(bboxes)
        for i in range(num_objs):
            ann = {}
            ann["image_id"] = image_id
            ann["bbox"] = bboxes[i]
            ann["category_id"] = labels[i]
            categories.add(labels[i])
            ann["area"] = areas[i]
            ann["iscrowd"] = iscrowd[i]
            ann["id"] = ann_id
            if "masks" in targets:
                ann["segmentation"] = coco_mask.encode(masks[i].numpy())
            if "keypoints" in targets:
                ann["keypoints"] = keypoints[i]
                ann["num_keypoints"] = sum(k != 0 for k in keypoints[i][2::3])
            dataset["annotations"].append(ann)
            ann_id += 1
    dataset["categories"] = [{"id": i} for i in sorted(categories)]
    coco_ds.dataset = dataset
    coco_ds.createIndex()
    return coco_ds

def get_coco_api_from_dataset(dataset):
    for _ in range(10):
        if isinstance(dataset, torchvision.datasets.CocoDetection):
            break
        if isinstance(dataset, torch.utils.data.Subset):
            dataset = dataset.dataset
    if isinstance(dataset, torchvision.datasets.CocoDetection):
        return dataset.coco
    return convert_to_coco_api(dataset)

def train_one_epoch(model, optimizer, data_loader, device, epoch, print_freq, scaler = None):
    model.train()
    metric_logger = MetricLogger(delimiter=" | ")
    metric_logger.add_meter("lr", SmoothedValue(window_size=1, fmt="{value:.6f}"))
    header = f"Result in epoch {epoch + 1} "

    lr_scheduler = None
    if epoch == 0:
        warmup_factor = 1.0 / 1000
        warmup_iters = min(1000, len(data_loader) - 1)

        lr_scheduler = torch.optim.lr_scheduler.LinearLR(
            optimizer, start_factor=warmup_factor, total_iters=warmup_iters
        )

    for idx, (images, targets) in enumerate(metric_logger.log_every(data_loader, print_freq, header)):
        images = list(image.to(device) for image in images)
        
        targets = [{k: v.to(device) for k, v in t.items()} for t in targets]  # change here
        
        # targets = [{k: v.to(device) for k, v in t.items()} for t in targets]
        with torch.cuda.amp.autocast(enabled=scaler is not None):
            loss_dict = model(images, targets)
            losses = sum(loss for loss in loss_dict.values())
        
        # reduce losses over all GPUs for logging purposes
        loss_dict_reduced = reduce_dict(loss_dict)
        losses_reduced = sum(loss for loss in loss_dict_reduced.values())

        loss_value = losses_reduced.item()
        
        if not math.isfinite(loss_value):
            print(f"Since the loss is {loss_value}, we will stop the training process...")
            print(loss_dict_reduced)
            sys.exit(1)

        optimizer.zero_grad()
        if scaler is not None:
            scaler.scale(losses).backward()
            scaler.step(optimizer)
            scaler.update()
        else:
            losses.backward()
            optimizer.step()

        if lr_scheduler is not None:
            lr_scheduler.step()

        metric_logger.update(loss=losses_reduced, **loss_dict_reduced)
        metric_logger.update(lr=optimizer.param_groups[0]["lr"])

    return metric_logger

def _get_iou_types(model):
    model_without_ddp = model
    if isinstance(model, torch.nn.parallel.DistributedDataParallel):
        model_without_ddp = model.module
    iou_types = ["bbox"]
    if isinstance(model_without_ddp, torchvision.models.detection.MaskRCNN):
        iou_types.append("segm")
    if isinstance(model_without_ddp, torchvision.models.detection.KeypointRCNN):
        iou_types.append("keypoints")
    return iou_types

# @torch.inference_mode()
def evaluate(model, data_loader, device):
    n_threads = torch.get_num_threads()
    # FIXME remove this and make paste_masks_in_image run on the GPU
    torch.set_num_threads(1)
    cpu_device = torch.device("cpu")
    model.eval()
    metric_logger = MetricLogger(delimiter=" | ")
    header = "Test process: "

    coco = get_coco_api_from_dataset(data_loader.dataset)
    iou_types = _get_iou_types(model)
    coco_evaluator = CocoEvaluator(coco, iou_types)

    for images, targets in metric_logger.log_every(data_loader, 100, header):
        
        images = list(img.to(device) for img in images)

        if torch.cuda.is_available(): torch.cuda.synchronize()
        model_time = time.time()
        outputs = model(images)      
        
        outputs = [{k: v.to(cpu_device) for k, v in t.items()} for t in outputs]
        model_time = time.time() - model_time

        res = {target["image_id"].item(): output for target, output in zip(targets, outputs)}
        evaluator_time = time.time()
        coco_evaluator.update(res)
        evaluator_time = time.time() - evaluator_time
        metric_logger.update(model_time=model_time, evaluation_time=evaluator_time)

    # gather the stats from all processes
    metric_logger.synchronize_between_processes()
    print(f"\nTest process statistics: {metric_logger}\n")
    coco_evaluator.synchronize_between_processes()

    # accumulate predictions from all images
    coco_evaluator.accumulate()
    coco_evaluator.summarize()
    torch.set_num_threads(n_threads)
    
    return coco_evaluator

class SmoothedValue:
    """Track a series of values and provide access to smoothed values over a
    window or the global series average.
    """

    def __init__(self, window_size=20, fmt=None):
        if fmt is None:
            fmt = "{median:.4f} ({global_avg:.4f})"
        self.deque = deque(maxlen=window_size)
        self.total = 0.0
        self.count = 0
        self.fmt = fmt

    def update(self, value, n=1):
        self.deque.append(value)
        self.count += n
        self.total += value * n

    def synchronize_between_processes(self):
        """
        Warning: does not synchronize the deque!
        """
        if not is_dist_avail_and_initialized():
            return
        t = torch.tensor([self.count, self.total], dtype=torch.float64, device="cuda")
        dist.barrier()
        dist.all_reduce(t)
        t = t.tolist()
        self.count = int(t[0])
        self.total = t[1]

    @property
    def median(self):
        d = torch.tensor(list(self.deque))
        return d.median().item()

    @property
    def avg(self):
        d = torch.tensor(list(self.deque), dtype=torch.float32)
        return d.mean().item()

    @property
    def global_avg(self):
        return self.total / self.count

    @property
    def max(self):
        return max(self.deque)

    @property
    def value(self):
        return self.deque[-1]

    def __str__(self):
        return self.fmt.format(
            median=self.median, avg=self.avg, global_avg=self.global_avg, max=self.max, value=self.value
        )

class MetricLogger:
    def __init__(self, delimiter=" | "):
        self.meters = defaultdict(SmoothedValue)
        self.delimiter = delimiter

    def update(self, **kwargs):
        for k, v in kwargs.items():
            if isinstance(v, torch.Tensor):
                v = v.item()
            assert isinstance(v, (float, int))
            self.meters[k].update(v)

    def __getattr__(self, attr):
        if attr in self.meters:
            return self.meters[attr]
        if attr in self.__dict__:
            return self.__dict__[attr]
        raise AttributeError(f"'{type(self).__name__}' object has no attribute '{attr}'")

    def __str__(self):
        loss_str = []
        for name, meter in self.meters.items():
            loss_str.append(f"{name}: {str(meter)}")
        return self.delimiter.join(loss_str)

    def synchronize_between_processes(self):
        for meter in self.meters.values():
            meter.synchronize_between_processes()

    def add_meter(self, name, meter):
        self.meters[name] = meter

    def log_every(self, iterable, print_freq, header=None):
        i = 0
        if not header:
            header = ""
        start_time = time.time()
        end = time.time()
        iter_time = SmoothedValue(fmt="{avg:.4f}")
        data_time = SmoothedValue(fmt="{avg:.4f}")
        space_fmt = ":" + str(len(str(len(iterable)))) + "d"
        if torch.cuda.is_available():
            init_msg = "".join(
                [
                    f"\n{header}",
                    "Result of {0" + space_fmt + "} out of {1} batches:\n",
                ]
            )
            
            log_msg = self.delimiter.join(
                [
                    "{meters}",
                    "time -> {time}",
                ]
            )
        else:
            log_msg = self.delimiter.join(
                [header, "[{0" + space_fmt + "}/{1}]", "eta: {eta}", "{meters}", "time: {time}", "data: {data}"]
            )
        MB = 1024.0 * 1024.0
        for obj in iterable:
            data_time.update(time.time() - end)
            yield obj
            iter_time.update(time.time() - end)
            if i % print_freq == 0 or i == len(iterable) - 1:
                eta_seconds = iter_time.global_avg * (len(iterable) - i)
                eta_string = str(datetime.timedelta(seconds=int(eta_seconds)))
                if torch.cuda.is_available():
                    print(init_msg.format(i + 1, len(iterable)))
                    print(
                        log_msg.format(
                            meters=str(self),
                            time=str(iter_time),
                        )
                    )
                else:
                    print(
                        log_msg.format(
                            i, len(iterable), eta=eta_string, meters=str(self), time=str(iter_time), data=str(data_time)
                        )
                    )
            i += 1
            end = time.time()
        total_time = time.time() - start_time
        total_time_str = str(datetime.timedelta(seconds=int(total_time)))
        print(f"{header} total time: {total_time_str} ({total_time / len(iterable):.4f} s / image)")
        
def reduce_dict(input_dict, average=True):
    """
    Args:
        input_dict (dict): all the values will be reduced
        average (bool): whether to do average or sum
    Reduce the values in the dictionary from all processes so that all processes
    have the averaged results. Returns a dict with the same fields as
    input_dict, after reduction.
    """
    world_size = get_world_size()
    if world_size < 2:
        return input_dict
    with torch.inference_mode():
        names = []
        values = []
        # sort the keys so that they are consistent across processes
        for k in sorted(input_dict.keys()):
            names.append(k)
            values.append(input_dict[k])
        values = torch.stack(values, dim=0)
        dist.all_reduce(values)
        if average:
            values /= world_size
        reduced_dict = {k: v for k, v in zip(names, values)}
    return reduced_dict

def get_world_size():
    if not is_dist_avail_and_initialized():
        return 1
    return dist.get_world_size()

def is_dist_avail_and_initialized():
    if not dist.is_available():
        return False
    if not dist.is_initialized():
        return False
    return True

# %%
model_prefix = "road"
epochs = 100
save_model_path = "saved_models"
for epoch in range(epochs):
    # train for one epoch, printing every 10 iterations
    train_one_epoch(m, optimizer, tr_dl, device, epoch, print_freq = 10)
    # update the learning rate
    lr_scheduler.step()
    # evaluate on the test dataset
    evaluate(m, val_dl, device = device)

os.makedirs(f"{save_model_path}", exist_ok = True)
torch.save(m, f"{save_model_path}/{model_prefix}_best_model.pt")
print("Training Complete!")
# Out:
# /tmp/ipykernel_31/3866963089.py:89: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=scaler is not None):
# Result in epoch 1 Result of   1 out of 176 batches:
#
# lr: 0.000007 | loss: 1.2674 (1.2674) | loss_classifier: 1.1108 (1.1108) | loss_box_reg: 0.0739 (0.0739) | loss_objectness: 0.0747 (0.0747) | loss_rpn_box_reg: 0.0080 (0.0080) | time -> 5.1567
#
# Result in epoch 1 Result of  11 out of 176 batches:
#
# lr: 0.000064 | loss: 1.2674 (1.0669) | loss_classifier: 1.0969 (0.9132) | loss_box_reg: 0.0739 (0.0771) | loss_objectness: 0.0641 (0.0682) | loss_rpn_box_reg: 0.0075 (0.0085) | time -> 1.5015
#
# Result in epoch 1 Result of  21 out of 176 batches:
#
# lr: 0.000121 | loss: 0.4675 (0.7196) | loss_classifier: 0.3593 (0.5852) | loss_box_reg: 0.0795 (0.0863) | loss_objectness: 0.0169 (0.0417) | loss_rpn_box_reg: 0.0040 (0.0064) | time -> 1.1050
#
# Result in epoch 1 Result of  31 out of 176 batches:
#
# lr: 0.000178 | loss: 0.3866 (0.6260) | loss_classifier: 0.2210 (0.4733) | loss_box_reg: 0.1108 (0.0969) | loss_objectness: 0.0100 (0.0487) | loss_rpn_box_reg: 0.0051 (0.0071) | time -> 1.0546
#
# Result in epoch 1 Result of  41 out of 176 batches:
#
# lr: 0.000235 | loss: 0.3897 (0.5507) | loss_classifier: 0.2294 (0.4014) | loss_box_reg: 0.1031 (0.0994) | loss_objectness: 0.0281 (0.0434) | loss_rpn_box_reg: 0.0053 (0.0066) | time -> 1.0639
#
# Result in epoch 1 Result of  51 out of 176 batches:
#
# lr: 0.000292 | loss: 0.2808 (0.4995) | loss_classifier: 0.1482 (0.3499) | loss_box_reg: 0.1031 (0.1037) | loss_objectness: 0.0210 (0.0396) | loss_rpn_box_reg: 0.0038 (0.0062) | time -> 1.0947
#
# Result in epoch 1 Result of  61 out of 176 batches:
#
# lr: 0.000349 | loss: 0.3002 (0.4678) | loss_classifier: 0.1482 (0.3167) | loss_box_reg: 0.1382 (0.1103) | loss_objectness: 0.0155 (0.0350) | loss_rpn_box_reg: 0.0032 (0.0058) | time -> 1.1037
#
# Result in epoch 1 Result of  71 out of 176 batches:
#
# lr: 0.000406 | loss: 0.3051 (0.4424) | loss_classifier: 0.1474 (0.2903) | loss_box_reg: 0.1412 (0.1157) | loss_objectness: 0.0036 (0.0310) | loss_rpn_box_reg: 0.0023 (0.0054) | time -> 1.1371
#
# Result in epoch 1 Result of  81 out of 176 batches:
#
# lr: 0.000463 | loss: 0.2740 (0.4219) | loss_classifier: 0.1142 (0.2687) | loss_box_reg: 0.1371 (0.1190) | loss_objectness: 0.0036 (0.0289) | loss_rpn_box_reg: 0.0026 (0.0052) | time -> 1.2117
#
# Result in epoch 1 Result of  91 out of 176 batches:
#
# lr: 0.000520 | loss: 0.2424 (0.4021) | loss_classifier: 0.1014 (0.2493) | loss_box_reg: 0.1329 (0.1205) | loss_objectness: 0.0066 (0.0271) | loss_rpn_box_reg: 0.0024 (0.0052) | time -> 1.2162
#
# Result in epoch 1 Result of 101 out of 176 batches:
#
# lr: 0.000578 | loss: 0.2191 (0.3974) | loss_classifier: 0.0852 (0.2337) | loss_box_reg: 0.1260 (0.1211) | loss_objectness: 0.0046 (0.0373) | loss_rpn_box_reg: 0.0024 (0.0053) | time -> 1.2340
#
# Result in epoch 1 Result of 111 out of 176 batches:
#
# lr: 0.000635 | loss: 0.1882 (0.3771) | loss_classifier: 0.0725 (0.2179) | loss_box_reg: 0.0967 (0.1175) | loss_objectness: 0.0079 (0.0366) | loss_rpn_box_reg: 0.0021 (0.0051) | time -> 1.2747
#
# Result in epoch 1 Result of 121 out of 176 batches:
#
# lr: 0.000692 | loss: 0.1844 (0.3626) | loss_classifier: 0.0625 (0.2061) | loss_box_reg: 0.0779 (0.1167) | loss_objectness: 0.0091 (0.0348) | loss_rpn_box_reg: 0.0030 (0.0051) | time -> 1.2570
#
# Result in epoch 1 Result of 131 out of 176 batches:
#
# lr: 0.000749 | loss: 0.1736 (0.3473) | loss_classifier: 0.0707 (0.1953) | loss_box_reg: 0.0878 (0.1140) | loss_objectness: 0.0037 (0.0331) | loss_rpn_box_reg: 0.0033 (0.0049) | time -> 1.2706
#
# Result in epoch 1 Result of 141 out of 176 batches:
#
# lr: 0.000806 | loss: 0.1382 (0.3314) | loss_classifier: 0.0523 (0.1854) | loss_box_reg: 0.0643 (0.1104) | loss_objectness: 0.0025 (0.0309) | loss_rpn_box_reg: 0.0024 (0.0047) | time -> 1.2486
#
# Result in epoch 1 Result of 151 out of 176 batches:
#
# lr: 0.000863 | loss: 0.1411 (0.3207) | loss_classifier: 0.0507 (0.1780) | loss_box_reg: 0.0739 (0.1086) | loss_objectness: 0.0016 (0.0294) | loss_rpn_box_reg: 0.0024 (0.0047) | time -> 1.2512
#
# Result in epoch 1 Result of 161 out of 176 batches:
#
# lr: 0.000920 | loss: 0.1505 (0.3114) | loss_classifier: 0.0685 (0.1716) | loss_box_reg: 0.0756 (0.1069) | loss_objectness: 0.0013 (0.0283) | loss_rpn_box_reg: 0.0029 (0.0047) | time -> 1.3001
#
# Result in epoch 1 Result of 171 out of 176 batches:
#
# lr: 0.000977 | loss: 0.1350 (0.3002) | loss_classifier: 0.0627 (0.1647) | loss_box_reg: 0.0643 (0.1041) | loss_objectness: 0.0025 (0.0269) | loss_rpn_box_reg: 0.0022 (0.0045) | time -> 1.2491
#
# Result in epoch 1 Result of 176 out of 176 batches:
#
# lr: 0.001000 | loss: 0.1272 (0.2947) | loss_classifier: 0.0561 (0.1613) | loss_box_reg: 0.0607 (0.1028) | loss_objectness: 0.0031 (0.0262) | loss_rpn_box_reg: 0.0018 (0.0044) | time -> 1.2056
# Result in epoch 1  total time: 0:03:33 (1.2113 s / image)
# creating index...
# index created!
#
# Test process: Result of  1 out of 22 batches:
#
# model_time: 0.5376 (0.5376) | evaluation_time: 0.0082 (0.0082) | time -> 0.8099
#
# Test process: Result of 22 out of 22 batches:
#
# model_time: 0.4794 (0.5485) | evaluation_time: 0.0041 (0.0043) | time -> 0.5714
# Test process:  total time: 0:00:12 (0.5797 s / image)
#
# Test process statistics: model_time: 0.4794 (0.5485) | evaluation_time: 0.0041 (0.0043)
#
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.257
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.421
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.254
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.321
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.274
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.331
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.291
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.410
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.410
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.391
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.409
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.429
#
# Result in epoch 2 Result of   1 out of 176 batches:
#
# lr: 0.001000 | loss: 0.0888 (0.0888) | loss_classifier: 0.0391 (0.0391) | loss_box_reg: 0.0356 (0.0356) | loss_objectness: 0.0131 (0.0131) | loss_rpn_box_reg: 0.0009 (0.0009) | time -> 1.3173
#
# Result in epoch 2 Result of  11 out of 176 batches:
#
# lr: 0.001000 | loss: 0.0816 (0.1235) | loss_classifier: 0.0306 (0.0528) | loss_box_reg: 0.0416 (0.0651) | loss_objectness: 0.0015 (0.0033) | loss_rpn_box_reg: 0.0018 (0.0023) | time -> 1.2910
#
# Result in epoch 2 Result of  21 out of 176 batches:
#
# lr: 0.001000 | loss: 0.0816 (0.1084) | loss_classifier: 0.0348 (0.0460) | loss_box_reg: 0.0475 (0.0567) | loss_objectness: 0.0012 (0.0033) | loss_rpn_box_reg: 0.0020 (0.0024) | time -> 1.2893
#
# Result in epoch 2 Result of  31 out of 176 batches:
#
# lr: 0.001000 | loss: 0.0938 (0.1167) | loss_classifier: 0.0364 (0.0467) | loss_box_reg: 0.0483 (0.0579) | loss_objectness: 0.0027 (0.0088) | loss_rpn_box_reg: 0.0023 (0.0033) | time -> 1.3166
#
# Result in epoch 2 Result of  41 out of 176 batches:
#
# lr: 0.001000 | loss: 0.0978 (0.1162) | loss_classifier: 0.0438 (0.0472) | loss_box_reg: 0.0517 (0.0576) | loss_objectness: 0.0044 (0.0083) | loss_rpn_box_reg: 0.0021 (0.0031) | time -> 1.3278
#
# Result in epoch 2 Result of  51 out of 176 batches:
#
# lr: 0.001000 | loss: 0.1238 (0.1199) | loss_classifier: 0.0521 (0.0479) | loss_box_reg: 0.0618 (0.0599) | loss_objectness: 0.0048 (0.0088) | loss_rpn_box_reg: 0.0021 (0.0033) | time -> 1.2504
#
# Result in epoch 2 Result of  61 out of 176 batches:
#
# lr: 0.001000 | loss: 0.1199 (0.1172) | loss_classifier: 0.0437 (0.0463) | loss_box_reg: 0.0618 (0.0594) | loss_objectness: 0.0048 (0.0084) | loss_rpn_box_reg: 0.0021 (0.0031) | time -> 1.2395
#
# Result in epoch 2 Result of  71 out of 176 batches:
#
# lr: 0.001000 | loss: 0.0762 (0.1117) | loss_classifier: 0.0262 (0.0436) | loss_box_reg: 0.0461 (0.0577) | loss_objectness: 0.0007 (0.0075) | loss_rpn_box_reg: 0.0012 (0.0028) | time -> 1.2425
#
# Result in epoch 2 Result of  81 out of 176 batches:
#
# lr: 0.001000 | loss: 0.0679 (0.1068) | loss_classifier: 0.0235 (0.0415) | loss_box_reg: 0.0424 (0.0555) | loss_objectness: 0.0007 (0.0071) | loss_rpn_box_reg: 0.0013 (0.0027) | time -> 1.1976
#
# Result in epoch 2 Result of  91 out of 176 batches:
#
# lr: 0.001000 | loss: 0.0699 (0.1044) | loss_classifier: 0.0288 (0.0409) | loss_box_reg: 0.0424 (0.0542) | loss_objectness: 0.0016 (0.0067) | loss_rpn_box_reg: 0.0015 (0.0026) | time -> 1.2568
#
# Result in epoch 2 Result of 101 out of 176 batches:
#
# lr: 0.001000 | loss: 0.0701 (0.1026) | loss_classifier: 0.0284 (0.0400) | loss_box_reg: 0.0428 (0.0536) | loss_objectness: 0.0012 (0.0065) | loss_rpn_box_reg: 0.0013 (0.0025) | time -> 1.2833
#
# Result in epoch 2 Result of 111 out of 176 batches:
#
# lr: 0.001000 | loss: 0.0878 (0.1025) | loss_classifier: 0.0282 (0.0396) | loss_box_reg: 0.0540 (0.0543) | loss_objectness: 0.0012 (0.0061) | loss_rpn_box_reg: 0.0017 (0.0025) | time -> 1.2529
#
# Result in epoch 2 Result of 121 out of 176 batches:
#
# lr: 0.001000 | loss: 0.0930 (0.1004) | loss_classifier: 0.0298 (0.0387) | loss_box_reg: 0.0540 (0.0533) | loss_objectness: 0.0011 (0.0059) | loss_rpn_box_reg: 0.0017 (0.0024) | time -> 1.2664
#
# Result in epoch 2 Result of 131 out of 176 batches:
#
# lr: 0.001000 | loss: 0.0873 (0.1020) | loss_classifier: 0.0267 (0.0389) | loss_box_reg: 0.0534 (0.0548) | loss_objectness: 0.0011 (0.0058) | loss_rpn_box_reg: 0.0014 (0.0025) | time -> 1.2959
#
# Result in epoch 2 Result of 141 out of 176 batches:
#
# lr: 0.001000 | loss: 0.0758 (0.0999) | loss_classifier: 0.0267 (0.0383) | loss_box_reg: 0.0501 (0.0537) | loss_objectness: 0.0013 (0.0055) | loss_rpn_box_reg: 0.0018 (0.0025) | time -> 1.3199
#
# Result in epoch 2 Result of 151 out of 176 batches:
#
# lr: 0.001000 | loss: 0.0746 (0.0991) | loss_classifier: 0.0253 (0.0375) | loss_box_reg: 0.0418 (0.0531) | loss_objectness: 0.0012 (0.0061) | loss_rpn_box_reg: 0.0018 (0.0025) | time -> 1.2574
#
# Result in epoch 2 Result of 161 out of 176 batches:
#
# lr: 0.001000 | loss: 0.0746 (0.0977) | loss_classifier: 0.0249 (0.0368) | loss_box_reg: 0.0449 (0.0525) | loss_objectness: 0.0018 (0.0060) | loss_rpn_box_reg: 0.0015 (0.0024) | time -> 1.1777
#
# Result in epoch 2 Result of 171 out of 176 batches:
#
# lr: 0.001000 | loss: 0.0719 (0.0964) | loss_classifier: 0.0235 (0.0362) | loss_box_reg: 0.0428 (0.0521) | loss_objectness: 0.0010 (0.0057) | loss_rpn_box_reg: 0.0014 (0.0024) | time -> 1.2275
#
# Result in epoch 2 Result of 176 out of 176 batches:
#
# lr: 0.001000 | loss: 0.0696 (0.0951) | loss_classifier: 0.0226 (0.0357) | loss_box_reg: 0.0427 (0.0514) | loss_objectness: 0.0008 (0.0056) | loss_rpn_box_reg: 0.0014 (0.0024) | time -> 1.2213
# Result in epoch 2  total time: 0:03:41 (1.2613 s / image)
# creating index...
# index created!
#
# Test process: Result of  1 out of 22 batches:
#
# model_time: 0.4872 (0.4872) | evaluation_time: 0.0052 (0.0052) | time -> 0.7246
#
# Test process: Result of 22 out of 22 batches:
#
# model_time: 0.4742 (0.5410) | evaluation_time: 0.0032 (0.0034) | time -> 0.5645
# Test process:  total time: 0:00:12 (0.5691 s / image)
#
# Test process statistics: model_time: 0.4742 (0.5410) | evaluation_time: 0.0032 (0.0034)
#
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.481
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.702
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.537
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.406
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.531
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.504
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.447
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.521
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.521
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.453
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.557
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.531
#
# Result in epoch 3 Result of   1 out of 176 batches:
#
# lr: 0.001000 | loss: 0.0284 (0.0284) | loss_classifier: 0.0140 (0.0140) | loss_box_reg: 0.0134 (0.0134) | loss_objectness: 0.0001 (0.0001) | loss_rpn_box_reg: 0.0009 (0.0009) | time -> 1.3405
#
# Result in epoch 3 Result of  11 out of 176 batches:
#
# lr: 0.001000 | loss: 0.0565 (0.0601) | loss_classifier: 0.0157 (0.0177) | loss_box_reg: 0.0396 (0.0400) | loss_objectness: 0.0010 (0.0008) | loss_rpn_box_reg: 0.0015 (0.0016) | time -> 1.2163
#
# Result in epoch 3 Result of  21 out of 176 batches:
#
# lr: 0.001000 | loss: 0.0691 (0.0720) | loss_classifier: 0.0186 (0.0239) | loss_box_reg: 0.0396 (0.0424) | loss_objectness: 0.0014 (0.0030) | loss_rpn_box_reg: 0.0018 (0.0028) | time -> 1.2776
#
# Result in epoch 3 Result of  31 out of 176 batches:
#
# lr: 0.001000 | loss: 0.0731 (0.0722) | loss_classifier: 0.0201 (0.0233) | loss_box_reg: 0.0399 (0.0434) | loss_objectness: 0.0030 (0.0028) | loss_rpn_box_reg: 0.0018 (0.0027) | time -> 1.3180
#
# Result in epoch 3 Result of  41 out of 176 batches:
#
# lr: 0.001000 | loss: 0.0614 (0.0711) | loss_classifier: 0.0177 (0.0230) | loss_box_reg: 0.0399 (0.0433) | loss_objectness: 0.0004 (0.0024) | loss_rpn_box_reg: 0.0018 (0.0025) | time -> 1.2216
#
# Result in epoch 3 Result of  51 out of 176 batches:
#
# lr: 0.001000 | loss: 0.0649 (0.0715) | loss_classifier: 0.0202 (0.0233) | loss_box_reg: 0.0452 (0.0433) | loss_objectness: 0.0004 (0.0026) | loss_rpn_box_reg: 0.0013 (0.0023) | time -> 1.2375
#
# Result in epoch 3 Result of  61 out of 176 batches:
#
# lr: 0.001000 | loss: 0.0649 (0.0683) | loss_classifier: 0.0178 (0.0222) | loss_box_reg: 0.0349 (0.0411) | loss_objectness: 0.0018 (0.0027) | loss_rpn_box_reg: 0.0012 (0.0023) | time -> 1.3003
#
# Result in epoch 3 Result of  71 out of 176 batches:
#
# lr: 0.001000 | loss: 0.0485 (0.0664) | loss_classifier: 0.0147 (0.0219) | loss_box_reg: 0.0288 (0.0398) | loss_objectness: 0.0010 (0.0026) | loss_rpn_box_reg: 0.0010 (0.0021) | time -> 1.2372
#
# Result in epoch 3 Result of  81 out of 176 batches:
#
# lr: 0.001000 | loss: 0.0603 (0.0658) | loss_classifier: 0.0161 (0.0216) | loss_box_reg: 0.0363 (0.0398) | loss_objectness: 0.0006 (0.0024) | loss_rpn_box_reg: 0.0010 (0.0021) | time -> 1.2157
#
# Result in epoch 3 Result of  91 out of 176 batches:
#
# lr: 0.001000 | loss: 0.0637 (0.0653) | loss_classifier: 0.0188 (0.0216) | loss_box_reg: 0.0411 (0.0394) | loss_objectness: 0.0003 (0.0022) | loss_rpn_box_reg: 0.0010 (0.0020) | time -> 1.2175
#
# Result in epoch 3 Result of 101 out of 176 batches:
#
# lr: 0.001000 | loss: 0.0637 (0.0663) | loss_classifier: 0.0227 (0.0219) | loss_box_reg: 0.0395 (0.0401) | loss_objectness: 0.0005 (0.0022) | loss_rpn_box_reg: 0.0010 (0.0020) | time -> 1.2653
#
# Result in epoch 3 Result of 111 out of 176 batches:
#
# lr: 0.001000 | loss: 0.0607 (0.0660) | loss_classifier: 0.0208 (0.0216) | loss_box_reg: 0.0370 (0.0398) | loss_objectness: 0.0006 (0.0027) | loss_rpn_box_reg: 0.0012 (0.0020) | time -> 1.3266
#
# Result in epoch 3 Result of 121 out of 176 batches:
#
# lr: 0.001000 | loss: 0.0620 (0.0673) | loss_classifier: 0.0178 (0.0218) | loss_box_reg: 0.0395 (0.0408) | loss_objectness: 0.0006 (0.0027) | loss_rpn_box_reg: 0.0010 (0.0020) | time -> 1.2612
#
# Result in epoch 3 Result of 131 out of 176 batches:
#
# lr: 0.001000 | loss: 0.0635 (0.0673) | loss_classifier: 0.0202 (0.0220) | loss_box_reg: 0.0399 (0.0407) | loss_objectness: 0.0010 (0.0027) | loss_rpn_box_reg: 0.0008 (0.0020) | time -> 1.2483
#
# Result in epoch 3 Result of 141 out of 176 batches:
#
# lr: 0.001000 | loss: 0.0543 (0.0661) | loss_classifier: 0.0177 (0.0216) | loss_box_reg: 0.0348 (0.0400) | loss_objectness: 0.0011 (0.0026) | loss_rpn_box_reg: 0.0010 (0.0020) | time -> 1.2827
#
# Result in epoch 3 Result of 151 out of 176 batches:
#
# lr: 0.001000 | loss: 0.0493 (0.0652) | loss_classifier: 0.0143 (0.0211) | loss_box_reg: 0.0317 (0.0397) | loss_objectness: 0.0007 (0.0025) | loss_rpn_box_reg: 0.0013 (0.0019) | time -> 1.2176
#
# Result in epoch 3 Result of 161 out of 176 batches:
#
# lr: 0.001000 | loss: 0.0493 (0.0655) | loss_classifier: 0.0140 (0.0212) | loss_box_reg: 0.0330 (0.0398) | loss_objectness: 0.0006 (0.0025) | loss_rpn_box_reg: 0.0008 (0.0020) | time -> 1.2246
#
# Result in epoch 3 Result of 171 out of 176 batches:
#
# lr: 0.001000 | loss: 0.0492 (0.0649) | loss_classifier: 0.0182 (0.0210) | loss_box_reg: 0.0330 (0.0394) | loss_objectness: 0.0006 (0.0025) | loss_rpn_box_reg: 0.0008 (0.0020) | time -> 1.3195
#
# Result in epoch 3 Result of 176 out of 176 batches:
#
# lr: 0.001000 | loss: 0.0575 (0.0646) | loss_classifier: 0.0185 (0.0210) | loss_box_reg: 0.0324 (0.0391) | loss_objectness: 0.0013 (0.0025) | loss_rpn_box_reg: 0.0009 (0.0020) | time -> 1.2580
# Result in epoch 3  total time: 0:03:41 (1.2559 s / image)
# creating index...
# index created!
#
# Test process: Result of  1 out of 22 batches:
#
# model_time: 0.5131 (0.5131) | evaluation_time: 0.0052 (0.0052) | time -> 0.7747
#
# Test process: Result of 22 out of 22 batches:
#
# model_time: 0.4792 (0.5469) | evaluation_time: 0.0029 (0.0030) | time -> 0.5695
# Test process:  total time: 0:00:12 (0.5766 s / image)
#
# Test process statistics: model_time: 0.4792 (0.5469) | evaluation_time: 0.0029 (0.0030)
#
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.547
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.722
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.683
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.422
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.588
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.606
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.503
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.574
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.574
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.447
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.612
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.618
#
# Result in epoch 4 Result of   1 out of 176 batches:
#
# lr: 0.000100 | loss: 0.0285 (0.0285) | loss_classifier: 0.0116 (0.0116) | loss_box_reg: 0.0158 (0.0158) | loss_objectness: 0.0001 (0.0001) | loss_rpn_box_reg: 0.0011 (0.0011) | time -> 1.2962
#
# Result in epoch 4 Result of  11 out of 176 batches:
#
# lr: 0.000100 | loss: 0.0495 (0.0544) | loss_classifier: 0.0168 (0.0187) | loss_box_reg: 0.0287 (0.0339) | loss_objectness: 0.0002 (0.0003) | loss_rpn_box_reg: 0.0014 (0.0015) | time -> 1.4842
#
# Result in epoch 4 Result of  21 out of 176 batches:
#
# lr: 0.000100 | loss: 0.0444 (0.0501) | loss_classifier: 0.0163 (0.0176) | loss_box_reg: 0.0284 (0.0303) | loss_objectness: 0.0003 (0.0009) | loss_rpn_box_reg: 0.0012 (0.0013) | time -> 1.4173
#
# Result in epoch 4 Result of  31 out of 176 batches:
#
# lr: 0.000100 | loss: 0.0488 (0.0533) | loss_classifier: 0.0159 (0.0183) | loss_box_reg: 0.0288 (0.0326) | loss_objectness: 0.0007 (0.0011) | loss_rpn_box_reg: 0.0009 (0.0014) | time -> 1.2959
#
# Result in epoch 4 Result of  41 out of 176 batches:
#
# lr: 0.000100 | loss: 0.0530 (0.0536) | loss_classifier: 0.0173 (0.0183) | loss_box_reg: 0.0322 (0.0320) | loss_objectness: 0.0008 (0.0017) | loss_rpn_box_reg: 0.0011 (0.0016) | time -> 1.2085
#
# Result in epoch 4 Result of  51 out of 176 batches:
#
# lr: 0.000100 | loss: 0.0513 (0.0520) | loss_classifier: 0.0141 (0.0176) | loss_box_reg: 0.0263 (0.0310) | loss_objectness: 0.0010 (0.0018) | loss_rpn_box_reg: 0.0011 (0.0016) | time -> 1.2275
#
# Result in epoch 4 Result of  61 out of 176 batches:
#
# lr: 0.000100 | loss: 0.0433 (0.0521) | loss_classifier: 0.0143 (0.0179) | loss_box_reg: 0.0280 (0.0310) | loss_objectness: 0.0003 (0.0017) | loss_rpn_box_reg: 0.0009 (0.0016) | time -> 1.3160
#
# Result in epoch 4 Result of  71 out of 176 batches:
#
# lr: 0.000100 | loss: 0.0516 (0.0525) | loss_classifier: 0.0178 (0.0179) | loss_box_reg: 0.0313 (0.0314) | loss_objectness: 0.0003 (0.0016) | loss_rpn_box_reg: 0.0010 (0.0016) | time -> 1.3270
#
# Result in epoch 4 Result of  81 out of 176 batches:
#
# lr: 0.000100 | loss: 0.0439 (0.0513) | loss_classifier: 0.0170 (0.0174) | loss_box_reg: 0.0279 (0.0307) | loss_objectness: 0.0003 (0.0016) | loss_rpn_box_reg: 0.0010 (0.0016) | time -> 1.3187
#
# Result in epoch 4 Result of  91 out of 176 batches:
#
# lr: 0.000100 | loss: 0.0439 (0.0514) | loss_classifier: 0.0143 (0.0172) | loss_box_reg: 0.0279 (0.0309) | loss_objectness: 0.0008 (0.0016) | loss_rpn_box_reg: 0.0013 (0.0016) | time -> 1.3214
#
# Result in epoch 4 Result of 101 out of 176 batches:
#
# lr: 0.000100 | loss: 0.0496 (0.0518) | loss_classifier: 0.0155 (0.0174) | loss_box_reg: 0.0312 (0.0313) | loss_objectness: 0.0008 (0.0016) | loss_rpn_box_reg: 0.0011 (0.0016) | time -> 1.3147
#
# Result in epoch 4 Result of 111 out of 176 batches:
#
# lr: 0.000100 | loss: 0.0408 (0.0508) | loss_classifier: 0.0160 (0.0171) | loss_box_reg: 0.0214 (0.0306) | loss_objectness: 0.0004 (0.0016) | loss_rpn_box_reg: 0.0008 (0.0015) | time -> 1.2259
#
# Result in epoch 4 Result of 121 out of 176 batches:
#
# lr: 0.000100 | loss: 0.0408 (0.0509) | loss_classifier: 0.0155 (0.0172) | loss_box_reg: 0.0245 (0.0305) | loss_objectness: 0.0003 (0.0016) | loss_rpn_box_reg: 0.0007 (0.0015) | time -> 1.1590
#
# Result in epoch 4 Result of 131 out of 176 batches:
#
# lr: 0.000100 | loss: 0.0437 (0.0507) | loss_classifier: 0.0131 (0.0170) | loss_box_reg: 0.0282 (0.0306) | loss_objectness: 0.0004 (0.0016) | loss_rpn_box_reg: 0.0009 (0.0015) | time -> 1.1436
#
# Result in epoch 4 Result of 141 out of 176 batches:
#
# lr: 0.000100 | loss: 0.0463 (0.0507) | loss_classifier: 0.0143 (0.0171) | loss_box_reg: 0.0306 (0.0307) | loss_objectness: 0.0005 (0.0015) | loss_rpn_box_reg: 0.0009 (0.0015) | time -> 1.1723
#
# Result in epoch 4 Result of 151 out of 176 batches:
#
# lr: 0.000100 | loss: 0.0463 (0.0510) | loss_classifier: 0.0165 (0.0172) | loss_box_reg: 0.0306 (0.0307) | loss_objectness: 0.0002 (0.0015) | loss_rpn_box_reg: 0.0009 (0.0016) | time -> 1.1904
#
# Result in epoch 4 Result of 161 out of 176 batches:
#
# lr: 0.000100 | loss: 0.0452 (0.0510) | loss_classifier: 0.0158 (0.0172) | loss_box_reg: 0.0277 (0.0307) | loss_objectness: 0.0001 (0.0015) | loss_rpn_box_reg: 0.0009 (0.0016) | time -> 1.1859
#
# Result in epoch 4 Result of 171 out of 176 batches:
#
# lr: 0.000100 | loss: 0.0458 (0.0513) | loss_classifier: 0.0154 (0.0173) | loss_box_reg: 0.0292 (0.0308) | loss_objectness: 0.0004 (0.0015) | loss_rpn_box_reg: 0.0010 (0.0017) | time -> 1.2713
#
# Result in epoch 4 Result of 176 out of 176 batches:
#
# lr: 0.000100 | loss: 0.0456 (0.0513) | loss_classifier: 0.0139 (0.0173) | loss_box_reg: 0.0291 (0.0308) | loss_objectness: 0.0003 (0.0015) | loss_rpn_box_reg: 0.0010 (0.0016) | time -> 1.2103
# Result in epoch 4  total time: 0:03:41 (1.2588 s / image)
# creating index...
# index created!
#
# Test process: Result of  1 out of 22 batches:
#
# model_time: 0.4968 (0.4968) | evaluation_time: 0.0050 (0.0050) | time -> 0.7189
#
# Test process: Result of 22 out of 22 batches:
#
# model_time: 0.4715 (0.5399) | evaluation_time: 0.0028 (0.0030) | time -> 0.5633
# Test process:  total time: 0:00:12 (0.5682 s / image)
#
# Test process statistics: model_time: 0.4715 (0.5399) | evaluation_time: 0.0028 (0.0030)
#
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.596
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.711
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.704
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.445
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.621
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.665
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.551
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.626
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.626
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.481
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.645
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.670
#
# Result in epoch 5 Result of   1 out of 176 batches:
#
# lr: 0.000100 | loss: 0.0581 (0.0581) | loss_classifier: 0.0195 (0.0195) | loss_box_reg: 0.0330 (0.0330) | loss_objectness: 0.0031 (0.0031) | loss_rpn_box_reg: 0.0025 (0.0025) | time -> 1.6308
#
# Result in epoch 5 Result of  11 out of 176 batches:
#
# lr: 0.000100 | loss: 0.0442 (0.0425) | loss_classifier: 0.0147 (0.0147) | loss_box_reg: 0.0267 (0.0253) | loss_objectness: 0.0002 (0.0012) | loss_rpn_box_reg: 0.0009 (0.0013) | time -> 1.3343
#
# Result in epoch 5 Result of  21 out of 176 batches:
#
# lr: 0.000100 | loss: 0.0391 (0.0474) | loss_classifier: 0.0147 (0.0169) | loss_box_reg: 0.0256 (0.0282) | loss_objectness: 0.0002 (0.0011) | loss_rpn_box_reg: 0.0009 (0.0013) | time -> 1.3626
#
# Result in epoch 5 Result of  31 out of 176 batches:
#
# lr: 0.000100 | loss: 0.0497 (0.0525) | loss_classifier: 0.0178 (0.0188) | loss_box_reg: 0.0323 (0.0305) | loss_objectness: 0.0006 (0.0012) | loss_rpn_box_reg: 0.0010 (0.0020) | time -> 1.2914
#
# Result in epoch 5 Result of  41 out of 176 batches:
#
# lr: 0.000100 | loss: 0.0531 (0.0512) | loss_classifier: 0.0180 (0.0182) | loss_box_reg: 0.0323 (0.0299) | loss_objectness: 0.0007 (0.0013) | loss_rpn_box_reg: 0.0009 (0.0017) | time -> 1.2047
#
# Result in epoch 5 Result of  51 out of 176 batches:
#
# lr: 0.000100 | loss: 0.0436 (0.0512) | loss_classifier: 0.0149 (0.0183) | loss_box_reg: 0.0280 (0.0300) | loss_objectness: 0.0006 (0.0012) | loss_rpn_box_reg: 0.0009 (0.0016) | time -> 1.1947
#
# Result in epoch 5 Result of  61 out of 176 batches:
#
# lr: 0.000100 | loss: 0.0436 (0.0505) | loss_classifier: 0.0146 (0.0182) | loss_box_reg: 0.0283 (0.0296) | loss_objectness: 0.0003 (0.0012) | loss_rpn_box_reg: 0.0010 (0.0016) | time -> 1.1991
#
# Result in epoch 5 Result of  71 out of 176 batches:
#
# lr: 0.000100 | loss: 0.0461 (0.0524) | loss_classifier: 0.0170 (0.0186) | loss_box_reg: 0.0304 (0.0309) | loss_objectness: 0.0004 (0.0013) | loss_rpn_box_reg: 0.0012 (0.0016) | time -> 1.2400
#
# Result in epoch 5 Result of  81 out of 176 batches:
#
# lr: 0.000100 | loss: 0.0461 (0.0518) | loss_classifier: 0.0156 (0.0182) | loss_box_reg: 0.0292 (0.0305) | loss_objectness: 0.0006 (0.0013) | loss_rpn_box_reg: 0.0019 (0.0018) | time -> 1.2857
#
# Result in epoch 5 Result of  91 out of 176 batches:
#
# lr: 0.000100 | loss: 0.0421 (0.0510) | loss_classifier: 0.0142 (0.0179) | loss_box_reg: 0.0254 (0.0302) | loss_objectness: 0.0004 (0.0012) | loss_rpn_box_reg: 0.0013 (0.0017) | time -> 1.2750
#
# Result in epoch 5 Result of 101 out of 176 batches:
#
# lr: 0.000100 | loss: 0.0432 (0.0502) | loss_classifier: 0.0141 (0.0175) | loss_box_reg: 0.0259 (0.0299) | loss_objectness: 0.0002 (0.0011) | loss_rpn_box_reg: 0.0008 (0.0016) | time -> 1.2765
#
# Result in epoch 5 Result of 111 out of 176 batches:
#
# lr: 0.000100 | loss: 0.0440 (0.0504) | loss_classifier: 0.0141 (0.0174) | loss_box_reg: 0.0280 (0.0303) | loss_objectness: 0.0001 (0.0011) | loss_rpn_box_reg: 0.0007 (0.0016) | time -> 1.3035
#
# Result in epoch 5 Result of 121 out of 176 batches:
#
# lr: 0.000100 | loss: 0.0447 (0.0504) | loss_classifier: 0.0151 (0.0175) | loss_box_reg: 0.0286 (0.0302) | loss_objectness: 0.0001 (0.0011) | loss_rpn_box_reg: 0.0007 (0.0016) | time -> 1.2812
#
# Result in epoch 5 Result of 131 out of 176 batches:
#
# lr: 0.000100 | loss: 0.0427 (0.0507) | loss_classifier: 0.0154 (0.0177) | loss_box_reg: 0.0257 (0.0302) | loss_objectness: 0.0002 (0.0012) | loss_rpn_box_reg: 0.0008 (0.0016) | time -> 1.2587
#
# Result in epoch 5 Result of 141 out of 176 batches:
#
# lr: 0.000100 | loss: 0.0461 (0.0507) | loss_classifier: 0.0165 (0.0176) | loss_box_reg: 0.0290 (0.0304) | loss_objectness: 0.0004 (0.0012) | loss_rpn_box_reg: 0.0008 (0.0015) | time -> 1.2722
#
# Result in epoch 5 Result of 151 out of 176 batches:
#
# lr: 0.000100 | loss: 0.0498 (0.0509) | loss_classifier: 0.0165 (0.0175) | loss_box_reg: 0.0317 (0.0305) | loss_objectness: 0.0005 (0.0013) | loss_rpn_box_reg: 0.0008 (0.0015) | time -> 1.3032
#
# Result in epoch 5 Result of 161 out of 176 batches:
#
# lr: 0.000100 | loss: 0.0403 (0.0504) | loss_classifier: 0.0125 (0.0173) | loss_box_reg: 0.0253 (0.0302) | loss_objectness: 0.0006 (0.0013) | loss_rpn_box_reg: 0.0016 (0.0016) | time -> 1.2456
#
# Result in epoch 5 Result of 171 out of 176 batches:
#
# lr: 0.000100 | loss: 0.0406 (0.0501) | loss_classifier: 0.0125 (0.0172) | loss_box_reg: 0.0236 (0.0300) | loss_objectness: 0.0008 (0.0013) | loss_rpn_box_reg: 0.0017 (0.0016) | time -> 1.1770
#
# Result in epoch 5 Result of 176 out of 176 batches:
#
# lr: 0.000100 | loss: 0.0406 (0.0495) | loss_classifier: 0.0123 (0.0170) | loss_box_reg: 0.0232 (0.0297) | loss_objectness: 0.0008 (0.0013) | loss_rpn_box_reg: 0.0011 (0.0015) | time -> 1.1636
# Result in epoch 5  total time: 0:03:41 (1.2598 s / image)
# creating index...
# index created!
#
# Test process: Result of  1 out of 22 batches:
#
# model_time: 0.5112 (0.5112) | evaluation_time: 0.0050 (0.0050) | time -> 0.7722
#
# Test process: Result of 22 out of 22 batches:
#
# model_time: 0.4742 (0.5463) | evaluation_time: 0.0029 (0.0029) | time -> 0.5689
# Test process:  total time: 0:00:12 (0.5760 s / image)
#
# Test process statistics: model_time: 0.4742 (0.5463) | evaluation_time: 0.0029 (0.0029)
#
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.596
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.714
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.709
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.445
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.624
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.664
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.547
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.622
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.622
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.479
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.647
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.669
#
# Result in epoch 6 Result of   1 out of 176 batches:
#
# lr: 0.000100 | loss: 0.0380 (0.0380) | loss_classifier: 0.0139 (0.0139) | loss_box_reg: 0.0233 (0.0233) | loss_objectness: 0.0002 (0.0002) | loss_rpn_box_reg: 0.0005 (0.0005) | time -> 1.7594
#
# Result in epoch 6 Result of  11 out of 176 batches:
#
# lr: 0.000100 | loss: 0.0448 (0.0496) | loss_classifier: 0.0160 (0.0165) | loss_box_reg: 0.0307 (0.0305) | loss_objectness: 0.0003 (0.0012) | loss_rpn_box_reg: 0.0013 (0.0014) | time -> 1.2858
#
# Result in epoch 6 Result of  21 out of 176 batches:
#
# lr: 0.000100 | loss: 0.0445 (0.0512) | loss_classifier: 0.0153 (0.0180) | loss_box_reg: 0.0283 (0.0307) | loss_objectness: 0.0004 (0.0009) | loss_rpn_box_reg: 0.0013 (0.0016) | time -> 1.2613
#
# Result in epoch 6 Result of  31 out of 176 batches:
#
# lr: 0.000100 | loss: 0.0442 (0.0521) | loss_classifier: 0.0151 (0.0183) | loss_box_reg: 0.0249 (0.0311) | loss_objectness: 0.0004 (0.0011) | loss_rpn_box_reg: 0.0014 (0.0016) | time -> 1.3188
#
# Result in epoch 6 Result of  41 out of 176 batches:
#
# lr: 0.000100 | loss: 0.0448 (0.0508) | loss_classifier: 0.0149 (0.0177) | loss_box_reg: 0.0235 (0.0306) | loss_objectness: 0.0006 (0.0010) | loss_rpn_box_reg: 0.0014 (0.0015) | time -> 1.3388
#
# Result in epoch 6 Result of  51 out of 176 batches:
#
# lr: 0.000100 | loss: 0.0396 (0.0498) | loss_classifier: 0.0132 (0.0173) | loss_box_reg: 0.0244 (0.0298) | loss_objectness: 0.0005 (0.0011) | loss_rpn_box_reg: 0.0010 (0.0016) | time -> 1.3243
#
# Result in epoch 6 Result of  61 out of 176 batches:
#
# lr: 0.000100 | loss: 0.0483 (0.0501) | loss_classifier: 0.0140 (0.0173) | loss_box_reg: 0.0291 (0.0302) | loss_objectness: 0.0008 (0.0010) | loss_rpn_box_reg: 0.0010 (0.0016) | time -> 1.2782
#
# Result in epoch 6 Result of  71 out of 176 batches:
#
# lr: 0.000100 | loss: 0.0483 (0.0503) | loss_classifier: 0.0140 (0.0172) | loss_box_reg: 0.0320 (0.0305) | loss_objectness: 0.0008 (0.0011) | loss_rpn_box_reg: 0.0010 (0.0016) | time -> 1.2023
#
# Result in epoch 6 Result of  81 out of 176 batches:
#
# lr: 0.000100 | loss: 0.0421 (0.0495) | loss_classifier: 0.0144 (0.0168) | loss_box_reg: 0.0258 (0.0300) | loss_objectness: 0.0006 (0.0012) | loss_rpn_box_reg: 0.0009 (0.0015) | time -> 1.2285
#
# Result in epoch 6 Result of  91 out of 176 batches:
#
# lr: 0.000100 | loss: 0.0394 (0.0498) | loss_classifier: 0.0148 (0.0170) | loss_box_reg: 0.0244 (0.0300) | loss_objectness: 0.0003 (0.0012) | loss_rpn_box_reg: 0.0009 (0.0016) | time -> 1.2807
#
# Result in epoch 6 Result of 101 out of 176 batches:
#
# lr: 0.000100 | loss: 0.0375 (0.0487) | loss_classifier: 0.0117 (0.0167) | loss_box_reg: 0.0201 (0.0293) | loss_objectness: 0.0002 (0.0012) | loss_rpn_box_reg: 0.0007 (0.0015) | time -> 1.3187
#
# Result in epoch 6 Result of 111 out of 176 batches:
#
# lr: 0.000100 | loss: 0.0397 (0.0486) | loss_classifier: 0.0127 (0.0166) | loss_box_reg: 0.0251 (0.0294) | loss_objectness: 0.0007 (0.0012) | loss_rpn_box_reg: 0.0006 (0.0014) | time -> 1.2623
#
# Result in epoch 6 Result of 121 out of 176 batches:
#
# lr: 0.000100 | loss: 0.0403 (0.0484) | loss_classifier: 0.0137 (0.0166) | loss_box_reg: 0.0251 (0.0291) | loss_objectness: 0.0007 (0.0012) | loss_rpn_box_reg: 0.0007 (0.0015) | time -> 1.2277
#
# Result in epoch 6 Result of 131 out of 176 batches:
#
# lr: 0.000100 | loss: 0.0425 (0.0482) | loss_classifier: 0.0142 (0.0164) | loss_box_reg: 0.0258 (0.0291) | loss_objectness: 0.0001 (0.0012) | loss_rpn_box_reg: 0.0009 (0.0015) | time -> 1.2579
#
# Result in epoch 6 Result of 141 out of 176 batches:
#
# lr: 0.000100 | loss: 0.0397 (0.0477) | loss_classifier: 0.0118 (0.0164) | loss_box_reg: 0.0222 (0.0286) | loss_objectness: 0.0002 (0.0012) | loss_rpn_box_reg: 0.0007 (0.0016) | time -> 1.2521
#
# Result in epoch 6 Result of 151 out of 176 batches:
#
# lr: 0.000100 | loss: 0.0350 (0.0477) | loss_classifier: 0.0122 (0.0164) | loss_box_reg: 0.0210 (0.0287) | loss_objectness: 0.0002 (0.0011) | loss_rpn_box_reg: 0.0006 (0.0015) | time -> 1.2004
#
# Result in epoch 6 Result of 161 out of 176 batches:
#
# lr: 0.000100 | loss: 0.0394 (0.0475) | loss_classifier: 0.0138 (0.0163) | loss_box_reg: 0.0241 (0.0285) | loss_objectness: 0.0002 (0.0012) | loss_rpn_box_reg: 0.0007 (0.0015) | time -> 1.1979
#
# Result in epoch 6 Result of 171 out of 176 batches:
#
# lr: 0.000100 | loss: 0.0426 (0.0481) | loss_classifier: 0.0141 (0.0165) | loss_box_reg: 0.0246 (0.0289) | loss_objectness: 0.0004 (0.0012) | loss_rpn_box_reg: 0.0013 (0.0015) | time -> 1.2972
#
# Result in epoch 6 Result of 176 out of 176 batches:
#
# lr: 0.000100 | loss: 0.0426 (0.0484) | loss_classifier: 0.0139 (0.0165) | loss_box_reg: 0.0286 (0.0292) | loss_objectness: 0.0004 (0.0012) | loss_rpn_box_reg: 0.0015 (0.0015) | time -> 1.2313
# Result in epoch 6  total time: 0:03:42 (1.2639 s / image)
# creating index...
# index created!
#
# Test process: Result of  1 out of 22 batches:
#
# model_time: 0.5062 (0.5062) | evaluation_time: 0.0045 (0.0045) | time -> 0.7209
#
# Test process: Result of 22 out of 22 batches:
#
# model_time: 0.4706 (0.5423) | evaluation_time: 0.0030 (0.0032) | time -> 0.5659
# Test process:  total time: 0:00:12 (0.5705 s / image)
#
# Test process statistics: model_time: 0.4706 (0.5423) | evaluation_time: 0.0030 (0.0032)
#
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.594
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.714
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.702
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.442
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.631
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.644
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.548
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.620
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.620
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.471
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.665
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.653
#
# Result in epoch 7 Result of   1 out of 176 batches:
#
# lr: 0.000010 | loss: 0.0347 (0.0347) | loss_classifier: 0.0099 (0.0099) | loss_box_reg: 0.0193 (0.0193) | loss_objectness: 0.0051 (0.0051) | loss_rpn_box_reg: 0.0004 (0.0004) | time -> 1.3027
#
# Result in epoch 7 Result of  11 out of 176 batches:
#
# lr: 0.000010 | loss: 0.0454 (0.0424) | loss_classifier: 0.0168 (0.0147) | loss_box_reg: 0.0259 (0.0254) | loss_objectness: 0.0003 (0.0011) | loss_rpn_box_reg: 0.0010 (0.0012) | time -> 1.3666
#
# Result in epoch 7 Result of  21 out of 176 batches:
#
# lr: 0.000010 | loss: 0.0496 (0.0480) | loss_classifier: 0.0170 (0.0167) | loss_box_reg: 0.0296 (0.0289) | loss_objectness: 0.0003 (0.0013) | loss_rpn_box_reg: 0.0010 (0.0012) | time -> 1.3366
#
# Result in epoch 7 Result of  31 out of 176 batches:
#
# lr: 0.000010 | loss: 0.0492 (0.0484) | loss_classifier: 0.0170 (0.0169) | loss_box_reg: 0.0274 (0.0292) | loss_objectness: 0.0001 (0.0010) | loss_rpn_box_reg: 0.0008 (0.0014) | time -> 1.2452
#
# Result in epoch 7 Result of  41 out of 176 batches:
#
# lr: 0.000010 | loss: 0.0443 (0.0497) | loss_classifier: 0.0153 (0.0170) | loss_box_reg: 0.0259 (0.0298) | loss_objectness: 0.0001 (0.0013) | loss_rpn_box_reg: 0.0013 (0.0015) | time -> 1.2645
#
# Result in epoch 7 Result of  51 out of 176 batches:
#
# lr: 0.000010 | loss: 0.0411 (0.0486) | loss_classifier: 0.0147 (0.0165) | loss_box_reg: 0.0228 (0.0293) | loss_objectness: 0.0006 (0.0013) | loss_rpn_box_reg: 0.0014 (0.0015) | time -> 1.2317
#
# Result in epoch 7 Result of  61 out of 176 batches:
#
# lr: 0.000010 | loss: 0.0342 (0.0488) | loss_classifier: 0.0135 (0.0166) | loss_box_reg: 0.0207 (0.0292) | loss_objectness: 0.0005 (0.0012) | loss_rpn_box_reg: 0.0011 (0.0017) | time -> 1.1911
#
# Result in epoch 7 Result of  71 out of 176 batches:
#
# lr: 0.000010 | loss: 0.0432 (0.0478) | loss_classifier: 0.0120 (0.0162) | loss_box_reg: 0.0268 (0.0288) | loss_objectness: 0.0004 (0.0012) | loss_rpn_box_reg: 0.0009 (0.0016) | time -> 1.2052
#
# Result in epoch 7 Result of  81 out of 176 batches:
#
# lr: 0.000010 | loss: 0.0389 (0.0468) | loss_classifier: 0.0110 (0.0158) | loss_box_reg: 0.0202 (0.0279) | loss_objectness: 0.0004 (0.0013) | loss_rpn_box_reg: 0.0008 (0.0018) | time -> 1.2075
#
# Result in epoch 7 Result of  91 out of 176 batches:
#
# lr: 0.000010 | loss: 0.0363 (0.0460) | loss_classifier: 0.0122 (0.0156) | loss_box_reg: 0.0197 (0.0274) | loss_objectness: 0.0006 (0.0012) | loss_rpn_box_reg: 0.0012 (0.0017) | time -> 1.2602
#
# Result in epoch 7 Result of 101 out of 176 batches:
#
# lr: 0.000010 | loss: 0.0365 (0.0457) | loss_classifier: 0.0135 (0.0156) | loss_box_reg: 0.0230 (0.0273) | loss_objectness: 0.0003 (0.0012) | loss_rpn_box_reg: 0.0007 (0.0017) | time -> 1.2643
#
# Result in epoch 7 Result of 111 out of 176 batches:
#
# lr: 0.000010 | loss: 0.0422 (0.0461) | loss_classifier: 0.0138 (0.0158) | loss_box_reg: 0.0232 (0.0275) | loss_objectness: 0.0001 (0.0012) | loss_rpn_box_reg: 0.0007 (0.0016) | time -> 1.3115
#
# Result in epoch 7 Result of 121 out of 176 batches:
#
# lr: 0.000010 | loss: 0.0419 (0.0458) | loss_classifier: 0.0145 (0.0157) | loss_box_reg: 0.0224 (0.0273) | loss_objectness: 0.0001 (0.0012) | loss_rpn_box_reg: 0.0009 (0.0016) | time -> 1.3193
#
# Result in epoch 7 Result of 131 out of 176 batches:
#
# lr: 0.000010 | loss: 0.0425 (0.0458) | loss_classifier: 0.0134 (0.0156) | loss_box_reg: 0.0269 (0.0275) | loss_objectness: 0.0002 (0.0011) | loss_rpn_box_reg: 0.0011 (0.0016) | time -> 1.2989
#
# Result in epoch 7 Result of 141 out of 176 batches:
#
# lr: 0.000010 | loss: 0.0460 (0.0467) | loss_classifier: 0.0156 (0.0160) | loss_box_reg: 0.0312 (0.0281) | loss_objectness: 0.0002 (0.0011) | loss_rpn_box_reg: 0.0012 (0.0015) | time -> 1.2650
#
# Result in epoch 7 Result of 151 out of 176 batches:
#
# lr: 0.000010 | loss: 0.0520 (0.0468) | loss_classifier: 0.0183 (0.0160) | loss_box_reg: 0.0305 (0.0282) | loss_objectness: 0.0002 (0.0011) | loss_rpn_box_reg: 0.0010 (0.0015) | time -> 1.2265
#
# Result in epoch 7 Result of 161 out of 176 batches:
#
# lr: 0.000010 | loss: 0.0520 (0.0472) | loss_classifier: 0.0185 (0.0163) | loss_box_reg: 0.0305 (0.0284) | loss_objectness: 0.0002 (0.0011) | loss_rpn_box_reg: 0.0010 (0.0015) | time -> 1.2495
#
# Result in epoch 7 Result of 171 out of 176 batches:
#
# lr: 0.000010 | loss: 0.0519 (0.0478) | loss_classifier: 0.0141 (0.0164) | loss_box_reg: 0.0307 (0.0287) | loss_objectness: 0.0002 (0.0012) | loss_rpn_box_reg: 0.0011 (0.0015) | time -> 1.2785
#
# Result in epoch 7 Result of 176 out of 176 batches:
#
# lr: 0.000010 | loss: 0.0352 (0.0472) | loss_classifier: 0.0117 (0.0162) | loss_box_reg: 0.0225 (0.0283) | loss_objectness: 0.0002 (0.0012) | loss_rpn_box_reg: 0.0011 (0.0015) | time -> 1.1779
# Result in epoch 7  total time: 0:03:41 (1.2573 s / image)
# creating index...
# index created!
#
# Test process: Result of  1 out of 22 batches:
#
# model_time: 0.5100 (0.5100) | evaluation_time: 0.0047 (0.0047) | time -> 0.7740
#
# Test process: Result of 22 out of 22 batches:
#
# model_time: 0.4747 (0.5446) | evaluation_time: 0.0029 (0.0030) | time -> 0.5686
# Test process:  total time: 0:00:12 (0.5753 s / image)
#
# Test process statistics: model_time: 0.4747 (0.5446) | evaluation_time: 0.0029 (0.0030)
#
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.594
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.714
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.702
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.443
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.633
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.641
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.548
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.620
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.620
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.473
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.666
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.648
#
# Result in epoch 8 Result of   1 out of 176 batches:
#
# lr: 0.000010 | loss: 0.0241 (0.0241) | loss_classifier: 0.0043 (0.0043) | loss_box_reg: 0.0195 (0.0195) | loss_objectness: 0.0000 (0.0000) | loss_rpn_box_reg: 0.0003 (0.0003) | time -> 1.3166
#
# Result in epoch 8 Result of  11 out of 176 batches:
#
# lr: 0.000010 | loss: 0.0480 (0.0494) | loss_classifier: 0.0152 (0.0161) | loss_box_reg: 0.0283 (0.0302) | loss_objectness: 0.0001 (0.0021) | loss_rpn_box_reg: 0.0007 (0.0010) | time -> 1.2194
#
# Result in epoch 8 Result of  21 out of 176 batches:
#
# lr: 0.000010 | loss: 0.0451 (0.0476) | loss_classifier: 0.0152 (0.0157) | loss_box_reg: 0.0278 (0.0286) | loss_objectness: 0.0002 (0.0018) | loss_rpn_box_reg: 0.0008 (0.0016) | time -> 1.2643
#
# Result in epoch 8 Result of  31 out of 176 batches:
#
# lr: 0.000010 | loss: 0.0437 (0.0485) | loss_classifier: 0.0169 (0.0161) | loss_box_reg: 0.0245 (0.0292) | loss_objectness: 0.0012 (0.0016) | loss_rpn_box_reg: 0.0011 (0.0016) | time -> 1.3079
#
# Result in epoch 8 Result of  41 out of 176 batches:
#
# lr: 0.000010 | loss: 0.0437 (0.0486) | loss_classifier: 0.0161 (0.0160) | loss_box_reg: 0.0303 (0.0295) | loss_objectness: 0.0008 (0.0014) | loss_rpn_box_reg: 0.0011 (0.0016) | time -> 1.3253
#
# Result in epoch 8 Result of  51 out of 176 batches:
#
# lr: 0.000010 | loss: 0.0373 (0.0462) | loss_classifier: 0.0122 (0.0153) | loss_box_reg: 0.0235 (0.0281) | loss_objectness: 0.0004 (0.0013) | loss_rpn_box_reg: 0.0007 (0.0015) | time -> 1.2710
#
# Result in epoch 8 Result of  61 out of 176 batches:
#
# lr: 0.000010 | loss: 0.0401 (0.0470) | loss_classifier: 0.0143 (0.0159) | loss_box_reg: 0.0232 (0.0285) | loss_objectness: 0.0002 (0.0013) | loss_rpn_box_reg: 0.0006 (0.0014) | time -> 1.2086
#
# Result in epoch 8 Result of  71 out of 176 batches:
#
# lr: 0.000010 | loss: 0.0507 (0.0478) | loss_classifier: 0.0173 (0.0159) | loss_box_reg: 0.0320 (0.0292) | loss_objectness: 0.0012 (0.0014) | loss_rpn_box_reg: 0.0009 (0.0014) | time -> 1.2325
#
# Result in epoch 8 Result of  81 out of 176 batches:
#
# lr: 0.000010 | loss: 0.0475 (0.0470) | loss_classifier: 0.0156 (0.0156) | loss_box_reg: 0.0296 (0.0288) | loss_objectness: 0.0009 (0.0013) | loss_rpn_box_reg: 0.0008 (0.0013) | time -> 1.1884
#
# Result in epoch 8 Result of  91 out of 176 batches:
#
# lr: 0.000010 | loss: 0.0408 (0.0468) | loss_classifier: 0.0135 (0.0156) | loss_box_reg: 0.0236 (0.0286) | loss_objectness: 0.0002 (0.0013) | loss_rpn_box_reg: 0.0007 (0.0013) | time -> 1.1593
#
# Result in epoch 8 Result of 101 out of 176 batches:
#
# lr: 0.000010 | loss: 0.0426 (0.0472) | loss_classifier: 0.0144 (0.0157) | loss_box_reg: 0.0282 (0.0289) | loss_objectness: 0.0003 (0.0013) | loss_rpn_box_reg: 0.0010 (0.0013) | time -> 1.2707
#
# Result in epoch 8 Result of 111 out of 176 batches:
#
# lr: 0.000010 | loss: 0.0440 (0.0466) | loss_classifier: 0.0134 (0.0155) | loss_box_reg: 0.0233 (0.0284) | loss_objectness: 0.0002 (0.0013) | loss_rpn_box_reg: 0.0009 (0.0013) | time -> 1.3790
#
# Result in epoch 8 Result of 121 out of 176 batches:
#
# lr: 0.000010 | loss: 0.0367 (0.0462) | loss_classifier: 0.0133 (0.0155) | loss_box_reg: 0.0221 (0.0281) | loss_objectness: 0.0001 (0.0013) | loss_rpn_box_reg: 0.0008 (0.0013) | time -> 1.3019
#
# Result in epoch 8 Result of 131 out of 176 batches:
#
# lr: 0.000010 | loss: 0.0367 (0.0456) | loss_classifier: 0.0133 (0.0153) | loss_box_reg: 0.0225 (0.0277) | loss_objectness: 0.0005 (0.0013) | loss_rpn_box_reg: 0.0007 (0.0013) | time -> 1.2194
#
# Result in epoch 8 Result of 141 out of 176 batches:
#
# lr: 0.000010 | loss: 0.0381 (0.0457) | loss_classifier: 0.0121 (0.0153) | loss_box_reg: 0.0235 (0.0278) | loss_objectness: 0.0004 (0.0013) | loss_rpn_box_reg: 0.0007 (0.0013) | time -> 1.2691
#
# Result in epoch 8 Result of 151 out of 176 batches:
#
# lr: 0.000010 | loss: 0.0397 (0.0465) | loss_classifier: 0.0133 (0.0155) | loss_box_reg: 0.0235 (0.0282) | loss_objectness: 0.0004 (0.0014) | loss_rpn_box_reg: 0.0015 (0.0014) | time -> 1.2347
#
# Result in epoch 8 Result of 161 out of 176 batches:
#
# lr: 0.000010 | loss: 0.0397 (0.0467) | loss_classifier: 0.0133 (0.0157) | loss_box_reg: 0.0260 (0.0282) | loss_objectness: 0.0005 (0.0014) | loss_rpn_box_reg: 0.0015 (0.0014) | time -> 1.1990
#
# Result in epoch 8 Result of 171 out of 176 batches:
#
# lr: 0.000010 | loss: 0.0455 (0.0474) | loss_classifier: 0.0148 (0.0159) | loss_box_reg: 0.0299 (0.0285) | loss_objectness: 0.0005 (0.0015) | loss_rpn_box_reg: 0.0011 (0.0015) | time -> 1.2705
#
# ...
#
# Result in epoch 98 Result of 111 out of 176 batches:
#
# lr: 0.000000 | loss: 0.0351 (0.0474) | loss_classifier: 0.0132 (0.0161) | loss_box_reg: 0.0219 (0.0285) | loss_objectness: 0.0008 (0.0012) | loss_rpn_box_reg: 0.0009 (0.0016) | time -> 1.2618
#
# Result in epoch 98 Result of 121 out of 176 batches:
#
# lr: 0.000000 | loss: 0.0400 (0.0467) | loss_classifier: 0.0140 (0.0159) | loss_box_reg: 0.0233 (0.0280) | loss_objectness: 0.0006 (0.0012) | loss_rpn_box_reg: 0.0010 (0.0016) | time -> 1.2361
#
# Result in epoch 98 Result of 131 out of 176 batches:
#
# lr: 0.000000 | loss: 0.0405 (0.0463) | loss_classifier: 0.0135 (0.0157) | loss_box_reg: 0.0249 (0.0279) | loss_objectness: 0.0007 (0.0012) | loss_rpn_box_reg: 0.0007 (0.0015) | time -> 1.2734
#
# Result in epoch 98 Result of 141 out of 176 batches:
#
# lr: 0.000000 | loss: 0.0423 (0.0460) | loss_classifier: 0.0135 (0.0156) | loss_box_reg: 0.0264 (0.0277) | loss_objectness: 0.0004 (0.0012) | loss_rpn_box_reg: 0.0007 (0.0015) | time -> 1.2542
#
# Result in epoch 98 Result of 151 out of 176 batches:
#
# lr: 0.000000 | loss: 0.0434 (0.0460) | loss_classifier: 0.0150 (0.0157) | loss_box_reg: 0.0269 (0.0277) | loss_objectness: 0.0004 (0.0012) | loss_rpn_box_reg: 0.0007 (0.0015) | time -> 1.2636
#
# Result in epoch 98 Result of 161 out of 176 batches:
#
# lr: 0.000000 | loss: 0.0437 (0.0460) | loss_classifier: 0.0130 (0.0156) | loss_box_reg: 0.0245 (0.0277) | loss_objectness: 0.0002 (0.0011) | loss_rpn_box_reg: 0.0008 (0.0015) | time -> 1.2438
#
# Result in epoch 98 Result of 171 out of 176 batches:
#
# lr: 0.000000 | loss: 0.0432 (0.0464) | loss_classifier: 0.0127 (0.0158) | loss_box_reg: 0.0243 (0.0281) | loss_objectness: 0.0001 (0.0011) | loss_rpn_box_reg: 0.0009 (0.0015) | time -> 1.2601
#
# Result in epoch 98 Result of 176 out of 176 batches:
#
# lr: 0.000000 | loss: 0.0418 (0.0463) | loss_classifier: 0.0127 (0.0157) | loss_box_reg: 0.0255 (0.0281) | loss_objectness: 0.0001 (0.0011) | loss_rpn_box_reg: 0.0009 (0.0015) | time -> 1.1933
# Result in epoch 98  total time: 0:03:41 (1.2591 s / image)
# creating index...
# index created!
#
# Test process: Result of  1 out of 22 batches:
#
# model_time: 0.4804 (0.4804) | evaluation_time: 0.0051 (0.0051) | time -> 0.7145
#
# Test process: Result of 22 out of 22 batches:
#
# model_time: 0.4761 (0.5458) | evaluation_time: 0.0028 (0.0029) | time -> 0.5698
# Test process:  total time: 0:00:12 (0.5744 s / image)
#
# Test process statistics: model_time: 0.4761 (0.5458) | evaluation_time: 0.0028 (0.0029)
#
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.589
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.714
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.702
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.438
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.627
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.640
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.542
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.614
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.614
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.468
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.654
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.648
#
# Result in epoch 99 Result of   1 out of 176 batches:
#
# lr: 0.000000 | loss: 0.0324 (0.0324) | loss_classifier: 0.0169 (0.0169) | loss_box_reg: 0.0131 (0.0131) | loss_objectness: 0.0006 (0.0006) | loss_rpn_box_reg: 0.0018 (0.0018) | time -> 1.4671
#
# Result in epoch 99 Result of  11 out of 176 batches:
#
# lr: 0.000000 | loss: 0.0440 (0.0418) | loss_classifier: 0.0156 (0.0155) | loss_box_reg: 0.0248 (0.0235) | loss_objectness: 0.0006 (0.0015) | loss_rpn_box_reg: 0.0011 (0.0013) | time -> 1.2736
#
# Result in epoch 99 Result of  21 out of 176 batches:
#
# lr: 0.000000 | loss: 0.0457 (0.0469) | loss_classifier: 0.0156 (0.0172) | loss_box_reg: 0.0270 (0.0275) | loss_objectness: 0.0004 (0.0011) | loss_rpn_box_reg: 0.0009 (0.0011) | time -> 1.2643
#
# Result in epoch 99 Result of  31 out of 176 batches:
#
# lr: 0.000000 | loss: 0.0458 (0.0478) | loss_classifier: 0.0155 (0.0167) | loss_box_reg: 0.0278 (0.0286) | loss_objectness: 0.0004 (0.0010) | loss_rpn_box_reg: 0.0007 (0.0014) | time -> 1.2713
#
# Result in epoch 99 Result of  41 out of 176 batches:
#
# lr: 0.000000 | loss: 0.0484 (0.0476) | loss_classifier: 0.0145 (0.0163) | loss_box_reg: 0.0295 (0.0289) | loss_objectness: 0.0003 (0.0010) | loss_rpn_box_reg: 0.0009 (0.0013) | time -> 1.2793
#
# Result in epoch 99 Result of  51 out of 176 batches:
#
# lr: 0.000000 | loss: 0.0497 (0.0475) | loss_classifier: 0.0145 (0.0164) | loss_box_reg: 0.0297 (0.0288) | loss_objectness: 0.0004 (0.0010) | loss_rpn_box_reg: 0.0009 (0.0013) | time -> 1.2681
#
# Result in epoch 99 Result of  61 out of 176 batches:
#
# lr: 0.000000 | loss: 0.0402 (0.0469) | loss_classifier: 0.0127 (0.0158) | loss_box_reg: 0.0260 (0.0287) | loss_objectness: 0.0002 (0.0012) | loss_rpn_box_reg: 0.0007 (0.0012) | time -> 1.2188
#
# Result in epoch 99 Result of  71 out of 176 batches:
#
# lr: 0.000000 | loss: 0.0376 (0.0475) | loss_classifier: 0.0119 (0.0161) | loss_box_reg: 0.0249 (0.0286) | loss_objectness: 0.0002 (0.0012) | loss_rpn_box_reg: 0.0010 (0.0015) | time -> 1.2563
#
# Result in epoch 99 Result of  81 out of 176 batches:
#
# lr: 0.000000 | loss: 0.0376 (0.0468) | loss_classifier: 0.0114 (0.0161) | loss_box_reg: 0.0249 (0.0280) | loss_objectness: 0.0006 (0.0012) | loss_rpn_box_reg: 0.0015 (0.0015) | time -> 1.2786
#
# Result in epoch 99 Result of  91 out of 176 batches:
#
# lr: 0.000000 | loss: 0.0371 (0.0460) | loss_classifier: 0.0132 (0.0158) | loss_box_reg: 0.0235 (0.0275) | loss_objectness: 0.0009 (0.0012) | loss_rpn_box_reg: 0.0015 (0.0015) | time -> 1.3248
#
# Result in epoch 99 Result of 101 out of 176 batches:
#
# lr: 0.000000 | loss: 0.0412 (0.0466) | loss_classifier: 0.0132 (0.0160) | loss_box_reg: 0.0264 (0.0278) | loss_objectness: 0.0005 (0.0012) | loss_rpn_box_reg: 0.0011 (0.0015) | time -> 1.3285
#
# Result in epoch 99 Result of 111 out of 176 batches:
#
# lr: 0.000000 | loss: 0.0412 (0.0462) | loss_classifier: 0.0129 (0.0158) | loss_box_reg: 0.0235 (0.0277) | loss_objectness: 0.0004 (0.0012) | loss_rpn_box_reg: 0.0010 (0.0015) | time -> 1.1819
#
# Result in epoch 99 Result of 121 out of 176 batches:
#
# lr: 0.000000 | loss: 0.0329 (0.0463) | loss_classifier: 0.0124 (0.0157) | loss_box_reg: 0.0214 (0.0278) | loss_objectness: 0.0005 (0.0012) | loss_rpn_box_reg: 0.0010 (0.0015) | time -> 1.1802
#
# Result in epoch 99 Result of 131 out of 176 batches:
#
# lr: 0.000000 | loss: 0.0384 (0.0465) | loss_classifier: 0.0132 (0.0158) | loss_box_reg: 0.0244 (0.0280) | loss_objectness: 0.0005 (0.0012) | loss_rpn_box_reg: 0.0008 (0.0015) | time -> 1.2118
#
# Result in epoch 99 Result of 141 out of 176 batches:
#
# lr: 0.000000 | loss: 0.0384 (0.0463) | loss_classifier: 0.0147 (0.0158) | loss_box_reg: 0.0260 (0.0278) | loss_objectness: 0.0004 (0.0012) | loss_rpn_box_reg: 0.0007 (0.0014) | time -> 1.2256
#
# Result in epoch 99 Result of 151 out of 176 batches:
#
# lr: 0.000000 | loss: 0.0399 (0.0460) | loss_classifier: 0.0128 (0.0156) | loss_box_reg: 0.0239 (0.0277) | loss_objectness: 0.0007 (0.0012) | loss_rpn_box_reg: 0.0010 (0.0015) | time -> 1.2589
#
# Result in epoch 99 Result of 161 out of 176 batches:
#
# lr: 0.000000 | loss: 0.0407 (0.0465) | loss_classifier: 0.0146 (0.0158) | loss_box_reg: 0.0239 (0.0280) | loss_objectness: 0.0007 (0.0012) | loss_rpn_box_reg: 0.0013 (0.0015) | time -> 1.3206
#
# Result in epoch 99 Result of 171 out of 176 batches:
#
# lr: 0.000000 | loss: 0.0424 (0.0467) | loss_classifier: 0.0153 (0.0158) | loss_box_reg: 0.0245 (0.0281) | loss_objectness: 0.0003 (0.0012) | loss_rpn_box_reg: 0.0009 (0.0015) | time -> 1.3252
#
# Result in epoch 99 Result of 176 out of 176 batches:
#
# lr: 0.000000 | loss: 0.0374 (0.0464) | loss_classifier: 0.0153 (0.0157) | loss_box_reg: 0.0245 (0.0280) | loss_objectness: 0.0002 (0.0012) | loss_rpn_box_reg: 0.0009 (0.0015) | time -> 1.1671
# Result in epoch 99  total time: 0:03:40 (1.2534 s / image)
# creating index...
# index created!
#
# Test process: Result of  1 out of 22 batches:
#
# model_time: 0.5165 (0.5165) | evaluation_time: 0.0049 (0.0049) | time -> 0.7650
#
# Test process: Result of 22 out of 22 batches:
#
# model_time: 0.4749 (0.5424) | evaluation_time: 0.0029 (0.0030) | time -> 0.5643
# Test process:  total time: 0:00:12 (0.5725 s / image)
#
# Test process statistics: model_time: 0.4749 (0.5424) | evaluation_time: 0.0029 (0.0030)
#
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.589
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.714
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.702
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.438
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.627
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.640
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.542
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.614
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.614
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.468
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.654
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.648
#
# Result in epoch 100 Result of   1 out of 176 batches:
#
# lr: 0.000000 | loss: 0.0569 (0.0569) | loss_classifier: 0.0190 (0.0190) | loss_box_reg: 0.0343 (0.0343) | loss_objectness: 0.0017 (0.0017) | loss_rpn_box_reg: 0.0019 (0.0019) | time -> 1.9581
#
# Result in epoch 100 Result of  11 out of 176 batches:
#
# lr: 0.000000 | loss: 0.0528 (0.0500) | loss_classifier: 0.0181 (0.0184) | loss_box_reg: 0.0290 (0.0288) | loss_objectness: 0.0006 (0.0013) | loss_rpn_box_reg: 0.0012 (0.0016) | time -> 1.2832
#
# Result in epoch 100 Result of  21 out of 176 batches:
#
# lr: 0.000000 | loss: 0.0473 (0.0487) | loss_classifier: 0.0165 (0.0168) | loss_box_reg: 0.0290 (0.0293) | loss_objectness: 0.0005 (0.0011) | loss_rpn_box_reg: 0.0009 (0.0014) | time -> 1.2872
#
# Result in epoch 100 Result of  31 out of 176 batches:
#
# lr: 0.000000 | loss: 0.0492 (0.0524) | loss_classifier: 0.0168 (0.0182) | loss_box_reg: 0.0300 (0.0311) | loss_objectness: 0.0004 (0.0014) | loss_rpn_box_reg: 0.0009 (0.0016) | time -> 1.3776
#
# Result in epoch 100 Result of  41 out of 176 batches:
#
# lr: 0.000000 | loss: 0.0445 (0.0506) | loss_classifier: 0.0143 (0.0177) | loss_box_reg: 0.0248 (0.0300) | loss_objectness: 0.0004 (0.0014) | loss_rpn_box_reg: 0.0009 (0.0015) | time -> 1.3153
#
# Result in epoch 100 Result of  51 out of 176 batches:
#
# lr: 0.000000 | loss: 0.0403 (0.0502) | loss_classifier: 0.0140 (0.0174) | loss_box_reg: 0.0243 (0.0298) | loss_objectness: 0.0007 (0.0014) | loss_rpn_box_reg: 0.0009 (0.0016) | time -> 1.2542
#
# Result in epoch 100 Result of  61 out of 176 batches:
#
# lr: 0.000000 | loss: 0.0404 (0.0480) | loss_classifier: 0.0127 (0.0163) | loss_box_reg: 0.0243 (0.0286) | loss_objectness: 0.0007 (0.0014) | loss_rpn_box_reg: 0.0011 (0.0016) | time -> 1.3007
#
# Result in epoch 100 Result of  71 out of 176 batches:
#
# lr: 0.000000 | loss: 0.0406 (0.0506) | loss_classifier: 0.0129 (0.0174) | loss_box_reg: 0.0268 (0.0302) | loss_objectness: 0.0005 (0.0014) | loss_rpn_box_reg: 0.0014 (0.0016) | time -> 1.2498
#
# Result in epoch 100 Result of  81 out of 176 batches:
#
# lr: 0.000000 | loss: 0.0585 (0.0507) | loss_classifier: 0.0153 (0.0173) | loss_box_reg: 0.0283 (0.0303) | loss_objectness: 0.0005 (0.0015) | loss_rpn_box_reg: 0.0010 (0.0016) | time -> 1.1281
#
# Result in epoch 100 Result of  91 out of 176 batches:
#
# lr: 0.000000 | loss: 0.0433 (0.0509) | loss_classifier: 0.0142 (0.0174) | loss_box_reg: 0.0283 (0.0304) | loss_objectness: 0.0004 (0.0015) | loss_rpn_box_reg: 0.0008 (0.0015) | time -> 1.1445
#
# Result in epoch 100 Result of 101 out of 176 batches:
#
# lr: 0.000000 | loss: 0.0370 (0.0495) | loss_classifier: 0.0128 (0.0169) | loss_box_reg: 0.0238 (0.0297) | loss_objectness: 0.0003 (0.0014) | loss_rpn_box_reg: 0.0008 (0.0015) | time -> 1.2364
#
# Result in epoch 100 Result of 111 out of 176 batches:
#
# lr: 0.000000 | loss: 0.0363 (0.0495) | loss_classifier: 0.0115 (0.0170) | loss_box_reg: 0.0213 (0.0293) | loss_objectness: 0.0003 (0.0014) | loss_rpn_box_reg: 0.0010 (0.0017) | time -> 1.2451
#
# Result in epoch 100 Result of 121 out of 176 batches:
#
# lr: 0.000000 | loss: 0.0392 (0.0489) | loss_classifier: 0.0115 (0.0168) | loss_box_reg: 0.0230 (0.0290) | loss_objectness: 0.0005 (0.0014) | loss_rpn_box_reg: 0.0014 (0.0017) | time -> 1.2426
#
# Result in epoch 100 Result of 131 out of 176 batches:
#
# lr: 0.000000 | loss: 0.0347 (0.0485) | loss_classifier: 0.0122 (0.0166) | loss_box_reg: 0.0230 (0.0288) | loss_objectness: 0.0005 (0.0014) | loss_rpn_box_reg: 0.0012 (0.0017) | time -> 1.3153
#
# Result in epoch 100 Result of 141 out of 176 batches:
#
# lr: 0.000000 | loss: 0.0383 (0.0479) | loss_classifier: 0.0137 (0.0164) | loss_box_reg: 0.0237 (0.0285) | loss_objectness: 0.0006 (0.0013) | loss_rpn_box_reg: 0.0010 (0.0017) | time -> 1.2895
#
# Result in epoch 100 Result of 151 out of 176 batches:
#
# lr: 0.000000 | loss: 0.0389 (0.0479) | loss_classifier: 0.0138 (0.0163) | loss_box_reg: 0.0237 (0.0286) | loss_objectness: 0.0002 (0.0014) | loss_rpn_box_reg: 0.0008 (0.0017) | time -> 1.2358
#
# Result in epoch 100 Result of 161 out of 176 batches:
#
# lr: 0.000000 | loss: 0.0385 (0.0472) | loss_classifier: 0.0135 (0.0161) | loss_box_reg: 0.0231 (0.0283) | loss_objectness: 0.0002 (0.0013) | loss_rpn_box_reg: 0.0006 (0.0016) | time -> 1.2530
#
# Result in epoch 100 Result of 171 out of 176 batches:
#
# lr: 0.000000 | loss: 0.0368 (0.0468) | loss_classifier: 0.0125 (0.0159) | loss_box_reg: 0.0220 (0.0281) | loss_objectness: 0.0002 (0.0013) | loss_rpn_box_reg: 0.0006 (0.0016) | time -> 1.2472
#
# Result in epoch 100 Result of 176 out of 176 batches:
#
# lr: 0.000000 | loss: 0.0377 (0.0467) | loss_classifier: 0.0128 (0.0159) | loss_box_reg: 0.0213 (0.0280) | loss_objectness: 0.0003 (0.0013) | loss_rpn_box_reg: 0.0007 (0.0015) | time -> 1.1962
# Result in epoch 100  total time: 0:03:40 (1.2551 s / image)
# creating index...
# index created!
#
# Test process: Result of  1 out of 22 batches:
#
# model_time: 0.4873 (0.4873) | evaluation_time: 0.0051 (0.0051) | time -> 0.7136
#
# Test process: Result of 22 out of 22 batches:
#
# model_time: 0.4723 (0.5430) | evaluation_time: 0.0028 (0.0030) | time -> 0.5674
# Test process:  total time: 0:00:12 (0.5719 s / image)
#
# Test process statistics: model_time: 0.4723 (0.5430) | evaluation_time: 0.0028 (0.0030)
#
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.589
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.714
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.702
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.438
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.627
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.640
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.542
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.614
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.614
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.468
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.654
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.648
# Training Complete!

# %%
def inference(model, ts_dl, num_ims, rows, threshold = 0.3, cmap = None):
    
    assert cmap in ["rgb", "gray"], "Determine whether the image is black and white or colored!"
    if cmap == "rgb": cmap = "vi9ridis"
    
    plt.figure(figsize = (20, 10))
    indekslar = [random.randint(0, len(ts_dl) - 1) for _ in range(num_ims)]
    
    for idx, indeks in enumerate(indekslar):
        im, _ = ts_dl.dataset[indeks]
        with torch.no_grad(): predictions = m(im.unsqueeze(0).to(device))
        img = tensor_2_im(im, inv_trans = True)
        bbox_class_names = []
        for i, (boxes, scores, labels) in enumerate(zip(predictions[0]["boxes"], predictions[0]["scores"], predictions[0]["labels"])):
            if scores > threshold:
                bbox_class_names.append(list(class_names.keys())[labels.item()])
                r, g, b = [random.randint(0, 255) for _ in range(3)]
                x, y, w, h = [round(b.item()) for b in boxes]
                cv2.rectangle(img = img, pt1 = (x, y), pt2 = (w, h), color = (r, g, b), thickness = 2)
        plt.subplot(rows, num_ims // rows, idx + 1)
        plt.imshow(img); plt.title(f"{bbox_class_names}")
        plt.axis("off")
        
inference(model = m, ts_dl = ts_dl, num_ims = 12, rows = 3, cmap = "rgb")
