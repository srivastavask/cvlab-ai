# %% [markdown]
# <a href="https://colab.research.google.com/github/itzrnvr/opencv-labs/blob/main/lab5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Task-1: Perform Image Compression Operations

# %%
import cv2
from PIL import Image
import matplotlib.pyplot as plt

# %%
IMG_SRC = 'picture2.jpg'
IMG_LOSSY = 'lossy_image.jpg'
IMG_LOSSLESS = 'lossless_image.png'

# %%
img_raw = cv2.imread(IMG_SRC)

# %%
img_rgb = cv2.cvtColor(img_raw, cv2.COLOR_BGR2RGB)

# %%
cv2.imwrite(IMG_LOSSY, img_raw, [cv2.IMWRITE_JPEG_QUALITY, 50])
cv2.imwrite(IMG_LOSSLESS, img_raw, [cv2.IMWRITE_PNG_COMPRESSION, 9])
cr_img_lossy = Image.open(IMG_LOSSY)
cr_img_lossless = Image.open(IMG_LOSSLESS)

# %%
plt.figure(figsize=(10, 10))
plt.subplot(1, 3, 1)
plt.imshow(img_rgb)
plt.title('Original Image')
plt.axis('off')
plt.subplot(1, 3, 2)
plt.imshow(cr_img_lossy)
plt.title('Lossy Compression (JPEG)')
plt.axis('off')
plt.subplot(1, 3, 3)
plt.imshow(cr_img_lossless)
plt.title('Lossless Compression (PNG)')
plt.axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Task-2: Apply Convolutional Neural Networks (CNN)

# %% [markdown]
# ### Part 1: Train CNN on the MNIST Dataset

# %%
from keras.datasets import mnist
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, roc_curve
import matplotlib.pyplot as plt

# %%
(_X_TRAIN, _Y_TRAIN), (_X_TEST, _Y_TEST) = mnist.load_data()
X_MNIST = _X_TRAIN.reshape(-1, 28, 28, 1).astype('float32') / 255
X_MNIST_TEST = _X_TEST.reshape(-1, 28, 28, 1).astype('float32') / 255
Y_MNIST = to_categorical(_Y_TRAIN)
Y_MNIST_TEST = to_categorical(_Y_TEST)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
net = Sequential()
net.add(Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)))
net.add(MaxPooling2D((2, 2)))
net.add(Conv2D(64, (3, 3), activation='relu'))
net.add(MaxPooling2D((2, 2)))
net.add(Flatten())
net.add(Dense(128, activation='relu'))
net.add(Dense(10, activation='softmax'))
net.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
his = net.fit(X_MNIST, Y_MNIST, validation_data=(X_MNIST_TEST, Y_MNIST_TEST), epochs=50, batch_size=128)
# Out:
# Epoch 1/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - accuracy: 0.8457 - loss: 0.5193 - val_accuracy: 0.9781 - val_loss: 0.0661
# Epoch 2/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9816 - loss: 0.0619 - val_accuracy: 0.9874 - val_loss: 0.0374
# Epoch 3/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9887 - loss: 0.0385 - val_accuracy: 0.9859 - val_loss: 0.0390
# Epoch 4/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9897 - loss: 0.0316 - val_accuracy: 0.9899 - val_loss: 0.0301
# Epoch 5/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9938 - loss: 0.0214 - val_accuracy: 0.9914 - val_loss: 0.0260
# Epoch 6/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9948 - loss: 0.0167 - val_accuracy: 0.9894 - val_loss: 0.0322
# Epoch 7/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9957 - loss: 0.0136 - val_accuracy: 0.9913 - val_loss: 0.0275
# Epoch 8/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9959 - loss: 0.0117 - val_accuracy: 0.9920 - val_loss: 0.0258
# Epoch 9/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9979 - loss: 0.0082 - val_accuracy: 0.9907 - val_loss: 0.0311
# Epoch 10/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9977 - loss: 0.0075 - val_accuracy: 0.9914 - val_loss: 0.0279
# Epoch 11/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9980 - loss: 0.0062 - val_accuracy: 0.9925 - val_loss: 0.0250
# Epoch 12/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9983 - loss: 0.0054 - val_accuracy: 0.9921 - val_loss: 0.0291
# Epoch 13/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9988 - loss: 0.0037 - val_accuracy: 0.9915 - val_loss: 0.0323
# Epoch 14/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9979 - loss: 0.0070 - val_accuracy: 0.9907 - val_loss: 0.0318
# Epoch 15/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9985 - loss: 0.0045 - val_accuracy: 0.9917 - val_loss: 0.0311
# Epoch 16/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9989 - loss: 0.0031 - val_accuracy: 0.9920 - val_loss: 0.0307
# Epoch 17/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9990 - loss: 0.0027 - val_accuracy: 0.9916 - val_loss: 0.0319
# Epoch 18/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9989 - loss: 0.0029 - val_accuracy: 0.9911 - val_loss: 0.0371
# Epoch 19/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9976 - loss: 0.0066 - val_accuracy: 0.9906 - val_loss: 0.0433
# Epoch 20/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9994 - loss: 0.0017 - val_accuracy: 0.9916 - val_loss: 0.0371
# Epoch 21/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9991 - loss: 0.0023 - val_accuracy: 0.9907 - val_loss: 0.0435
# Epoch 22/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9989 - loss: 0.0037 - val_accuracy: 0.9927 - val_loss: 0.0384
# Epoch 23/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9995 - loss: 0.0016 - val_accuracy: 0.9908 - val_loss: 0.0446
# Epoch 24/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9986 - loss: 0.0037 - val_accuracy: 0.9919 - val_loss: 0.0358
# Epoch 25/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9996 - loss: 0.0012 - val_accuracy: 0.9917 - val_loss: 0.0386
# Epoch 26/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9997 - loss: 8.8680e-04 - val_accuracy: 0.9893 - val_loss: 0.0505
# Epoch 27/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9990 - loss: 0.0030 - val_accuracy: 0.9916 - val_loss: 0.0448
# Epoch 28/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9992 - loss: 0.0020 - val_accuracy: 0.9897 - val_loss: 0.0437
# Epoch 29/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9997 - loss: 8.6301e-04 - val_accuracy: 0.9921 - val_loss: 0.0407
# Epoch 30/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9990 - loss: 0.0037 - val_accuracy: 0.9918 - val_loss: 0.0418
# Epoch 31/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9996 - loss: 0.0011 - val_accuracy: 0.9909 - val_loss: 0.0476
# Epoch 32/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9986 - loss: 0.0040 - val_accuracy: 0.9904 - val_loss: 0.0498
# Epoch 33/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9998 - loss: 7.3026e-04 - val_accuracy: 0.9905 - val_loss: 0.0521
# Epoch 34/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9989 - loss: 0.0035 - val_accuracy: 0.9907 - val_loss: 0.0480
# Epoch 35/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9995 - loss: 0.0017 - val_accuracy: 0.9913 - val_loss: 0.0504
# Epoch 36/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9996 - loss: 0.0012 - val_accuracy: 0.9924 - val_loss: 0.0449
# Epoch 37/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9996 - loss: 8.5406e-04 - val_accuracy: 0.9925 - val_loss: 0.0372
# Epoch 38/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9992 - loss: 0.0024 - val_accuracy: 0.9928 - val_loss: 0.0398
# Epoch 39/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9997 - loss: 7.8222e-04 - val_accuracy: 0.9925 - val_loss: 0.0389
# Epoch 40/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 9.6745e-05 - val_accuracy: 0.9926 - val_loss: 0.0419
# Epoch 41/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 1.0000 - loss: 1.5239e-05 - val_accuracy: 0.9928 - val_loss: 0.0417
# Epoch 42/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 7.7627e-06 - val_accuracy: 0.9928 - val_loss: 0.0422
# Epoch 43/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 1.0000 - loss: 5.4828e-06 - val_accuracy: 0.9929 - val_loss: 0.0427
# Epoch 44/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 1.0000 - loss: 4.6571e-06 - val_accuracy: 0.9929 - val_loss: 0.0432
# Epoch 45/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 3.0743e-06 - val_accuracy: 0.9931 - val_loss: 0.0438
# Epoch 46/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 1.0000 - loss: 2.5500e-06 - val_accuracy: 0.9930 - val_loss: 0.0444
# Epoch 47/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 2.1653e-06 - val_accuracy: 0.9932 - val_loss: 0.0449
# Epoch 48/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 1.6818e-06 - val_accuracy: 0.9932 - val_loss: 0.0455
# Epoch 49/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 1.4899e-06 - val_accuracy: 0.9932 - val_loss: 0.0463
# Epoch 50/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 1.0000 - loss: 1.1220e-06 - val_accuracy: 0.9932 - val_loss: 0.0467

# %%
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc, roc_auc_score
import numpy as np
import seaborn as sns
pred_mnist = net.predict(X_MNIST_TEST)
mnist_pred_lbl = np.argmax(pred_mnist, axis=1)
mnist_true_lbl = np.argmax(Y_MNIST_TEST, axis=1)
mat_mnist = confusion_matrix(mnist_true_lbl, mnist_pred_lbl)
plt.figure(figsize=(10, 8))
sns.heatmap(mat_mnist, annot=True, fmt='g', cmap='Blues', cbar=False, linewidths=0.5, linecolor='gray')
plt.title('Confusion Matrix for MNIST', fontsize=16)
plt.xlabel('Predicted Labels', fontsize=14)
plt.ylabel('True Labels', fontsize=14)
plt.show()
rep_mnist = classification_report(mnist_true_lbl, mnist_pred_lbl, digits=4)
print('Classification Report:\n', rep_mnist)
acc_mnist = np.sum(mnist_true_lbl == mnist_pred_lbl) / len(mnist_true_lbl)
print(f'Accuracy: {acc_mnist * 100:.2f}%')
fpr_dict = dict()
tpr_dict = dict()
roc_auc_dict = dict()
for ind in range(10):
    fpr_dict[ind], tpr_dict[ind], _ = roc_curve(Y_MNIST_TEST[:, ind], pred_mnist[:, ind])
    roc_auc_dict[ind] = auc(fpr_dict[ind], tpr_dict[ind])
plt.figure()
plt.plot(fpr_dict[0], tpr_dict[0], color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc_dict[0]:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve for Class 0')
plt.legend(loc='lower right')
plt.show()
auc_value_mnist = roc_auc_score(Y_MNIST_TEST, pred_mnist, average='macro')
print(f'Overall AUC Score: {auc_value_mnist:.4f}')
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#            0     0.9959    0.9969    0.9964       980
#            1     0.9947    0.9982    0.9965      1135
#            2     0.9942    0.9922    0.9932      1032
#            3     0.9901    0.9950    0.9926      1010
#            4     0.9909    0.9959    0.9934       982
#            5     0.9910    0.9922    0.9916       892
#            6     0.9989    0.9916    0.9953       958
#            7     0.9893    0.9922    0.9908      1028
#            8     0.9928    0.9938    0.9933       974
#            9     0.9940    0.9832    0.9885      1009
#
#     accuracy                         0.9932     10000
#    macro avg     0.9932    0.9931    0.9932     10000
# weighted avg     0.9932    0.9932    0.9932     10000
#
# Accuracy: 99.32%
# Overall AUC Score: 0.9999

# %% [markdown]
# ### Part 2: Train CNN on the CIFAR-10 Dataset

# %%
from keras.datasets import cifar10
(cifarx_train, cifary_train), (cifarx_test, cifary_test) = cifar10.load_data()
cifarx_train = cifarx_train.astype('float32') / 255
cifarx_test = cifarx_test.astype('float32') / 255
from keras.utils import to_categorical
cifary_train = to_categorical(cifary_train)
cifary_test = to_categorical(cifary_test)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 6s 0us/step

# %%
cnn_cifar = Sequential()
cnn_cifar.add(Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)))
cnn_cifar.add(MaxPooling2D((2, 2)))
cnn_cifar.add(Conv2D(64, (3, 3), activation='relu'))
cnn_cifar.add(MaxPooling2D((2, 2)))
cnn_cifar.add(Flatten())
cnn_cifar.add(Dense(128, activation='relu'))
cnn_cifar.add(Dense(10, activation='softmax'))
cnn_cifar.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
cifar_history = cnn_cifar.fit(cifarx_train, cifary_train, validation_data=(cifarx_test, cifary_test), epochs=50, batch_size=128)
# Out:
# Epoch 1/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.3605 - loss: 1.7631 - val_accuracy: 0.5382 - val_loss: 1.3015
# Epoch 2/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.5577 - loss: 1.2434 - val_accuracy: 0.5896 - val_loss: 1.1674
# Epoch 3/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.6102 - loss: 1.1077 - val_accuracy: 0.6314 - val_loss: 1.0628
# Epoch 4/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.6437 - loss: 1.0112 - val_accuracy: 0.6521 - val_loss: 0.9950
# Epoch 5/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.6783 - loss: 0.9271 - val_accuracy: 0.6573 - val_loss: 0.9852
# Epoch 6/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.6957 - loss: 0.8714 - val_accuracy: 0.6664 - val_loss: 0.9633
# Epoch 7/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7129 - loss: 0.8284 - val_accuracy: 0.6884 - val_loss: 0.9089
# Epoch 8/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.7352 - loss: 0.7611 - val_accuracy: 0.6985 - val_loss: 0.8846
# Epoch 9/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7502 - loss: 0.7196 - val_accuracy: 0.6992 - val_loss: 0.8923
# Epoch 10/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7605 - loss: 0.6821 - val_accuracy: 0.7027 - val_loss: 0.8736
# Epoch 11/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7766 - loss: 0.6430 - val_accuracy: 0.7020 - val_loss: 0.8811
# Epoch 12/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.7937 - loss: 0.5963 - val_accuracy: 0.7031 - val_loss: 0.8866
# Epoch 13/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8101 - loss: 0.5480 - val_accuracy: 0.7045 - val_loss: 0.8983
# Epoch 14/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8241 - loss: 0.5148 - val_accuracy: 0.7004 - val_loss: 0.9253
# Epoch 15/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8352 - loss: 0.4813 - val_accuracy: 0.7140 - val_loss: 0.9045
# Epoch 16/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8490 - loss: 0.4417 - val_accuracy: 0.7087 - val_loss: 0.9336
# Epoch 17/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8627 - loss: 0.4020 - val_accuracy: 0.7147 - val_loss: 0.9438
# Epoch 18/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8702 - loss: 0.3839 - val_accuracy: 0.7036 - val_loss: 0.9982
# Epoch 19/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8800 - loss: 0.3563 - val_accuracy: 0.7033 - val_loss: 1.0187
# Epoch 20/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8910 - loss: 0.3171 - val_accuracy: 0.7092 - val_loss: 1.0426
# Epoch 21/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9032 - loss: 0.2867 - val_accuracy: 0.7056 - val_loss: 1.0736
# Epoch 22/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9133 - loss: 0.2613 - val_accuracy: 0.7062 - val_loss: 1.1365
# Epoch 23/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9214 - loss: 0.2366 - val_accuracy: 0.7042 - val_loss: 1.1495
# Epoch 24/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9308 - loss: 0.2124 - val_accuracy: 0.7001 - val_loss: 1.2174
# Epoch 25/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9325 - loss: 0.2050 - val_accuracy: 0.6957 - val_loss: 1.2868
# Epoch 26/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9384 - loss: 0.1869 - val_accuracy: 0.6991 - val_loss: 1.3246
# Epoch 27/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9495 - loss: 0.1597 - val_accuracy: 0.6933 - val_loss: 1.3939
# Epoch 28/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9576 - loss: 0.1362 - val_accuracy: 0.6966 - val_loss: 1.4601
# Epoch 29/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9611 - loss: 0.1259 - val_accuracy: 0.6856 - val_loss: 1.6211
# Epoch 30/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9606 - loss: 0.1237 - val_accuracy: 0.6999 - val_loss: 1.5882
# Epoch 31/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9662 - loss: 0.1059 - val_accuracy: 0.6898 - val_loss: 1.7442
# Epoch 32/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9657 - loss: 0.1055 - val_accuracy: 0.6880 - val_loss: 1.7564
# Epoch 33/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9709 - loss: 0.0916 - val_accuracy: 0.6888 - val_loss: 1.7964
# Epoch 34/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9744 - loss: 0.0829 - val_accuracy: 0.6927 - val_loss: 1.8683
# Epoch 35/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9732 - loss: 0.0822 - val_accuracy: 0.6878 - val_loss: 1.9020
# Epoch 36/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9798 - loss: 0.0686 - val_accuracy: 0.6920 - val_loss: 1.9419
# Epoch 37/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9835 - loss: 0.0595 - val_accuracy: 0.6924 - val_loss: 2.0979
# Epoch 38/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9826 - loss: 0.0566 - val_accuracy: 0.6925 - val_loss: 2.1120
# Epoch 39/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9785 - loss: 0.0643 - val_accuracy: 0.6928 - val_loss: 2.1315
# Epoch 40/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9739 - loss: 0.0765 - val_accuracy: 0.6861 - val_loss: 2.2734
# Epoch 41/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9855 - loss: 0.0475 - val_accuracy: 0.6806 - val_loss: 2.3688
# Epoch 42/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9800 - loss: 0.0591 - val_accuracy: 0.6934 - val_loss: 2.3418
# Epoch 43/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9863 - loss: 0.0416 - val_accuracy: 0.6937 - val_loss: 2.3442
# Epoch 44/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9899 - loss: 0.0351 - val_accuracy: 0.6774 - val_loss: 2.4780
# Epoch 45/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9712 - loss: 0.0810 - val_accuracy: 0.6834 - val_loss: 2.5118
# Epoch 46/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9815 - loss: 0.0570 - val_accuracy: 0.6887 - val_loss: 2.5357
# Epoch 47/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9835 - loss: 0.0487 - val_accuracy: 0.6897 - val_loss: 2.4808
# Epoch 48/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9831 - loss: 0.0494 - val_accuracy: 0.6875 - val_loss: 2.5450
# Epoch 49/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9894 - loss: 0.0335 - val_accuracy: 0.6948 - val_loss: 2.6636
# Epoch 50/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9934 - loss: 0.0233 - val_accuracy: 0.6920 - val_loss: 2.6904

# %%
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc, roc_auc_score
import numpy as np
import seaborn as sns
pred_cifar = cnn_cifar.predict(cifarx_test)
cifar_pred_lbl = np.argmax(pred_cifar, axis=1)
cifar_true_lbl = np.argmax(cifary_test, axis=1)
mat_cifar = confusion_matrix(cifar_true_lbl, cifar_pred_lbl)
plt.figure(figsize=(10, 8))
sns.heatmap(mat_cifar, annot=True, fmt='g', cmap='Blues', cbar=False, linewidths=0.5, linecolor='gray')
plt.title('Confusion Matrix for CIFAR-10 - Model2', fontsize=16)
plt.xlabel('Predicted Labels', fontsize=14)
plt.ylabel('True Labels', fontsize=14)
plt.show()
rep_cifar = classification_report(cifar_true_lbl, cifar_pred_lbl, digits=4)
print('Classification Report:\n', rep_cifar)
acc_cifar = np.sum(cifar_true_lbl == cifar_pred_lbl) / len(cifar_true_lbl)
print(f'Accuracy: {acc_cifar * 100:.2f}%')
fpr_cifar = dict()
tpr_cifar = dict()
roc_auc_cifar = dict()
for ind in range(10):
    fpr_cifar[ind], tpr_cifar[ind], _ = roc_curve(cifary_test[:, ind], pred_cifar[:, ind])
    roc_auc_cifar[ind] = auc(fpr_cifar[ind], tpr_cifar[ind])
plt.figure()
plt.plot(fpr_cifar[0], tpr_cifar[0], color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc_cifar[0]:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve for Class 0')
plt.legend(loc='lower right')
plt.show()
auc_value_cifar = roc_auc_score(cifary_test, pred_cifar, average='macro')
print(f'Overall AUC Score: {auc_value_cifar:.4f}')
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#            0     0.7229    0.7410    0.7319      1000
#            1     0.7597    0.8380    0.7970      1000
#            2     0.6286    0.5500    0.5867      1000
#            3     0.5323    0.4700    0.4992      1000
#            4     0.6652    0.6120    0.6375      1000
#            5     0.5545    0.6460    0.5968      1000
#            6     0.7142    0.7870    0.7488      1000
#            7     0.7300    0.7490    0.7394      1000
#            8     0.8284    0.7630    0.7944      1000
#            9     0.7796    0.7640    0.7717      1000
#
#     accuracy                         0.6920     10000
#    macro avg     0.6915    0.6920    0.6903     10000
# weighted avg     0.6915    0.6920    0.6903     10000
#
# Accuracy: 69.20%
# Overall AUC Score: 0.9463
